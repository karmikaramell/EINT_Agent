# %%
import os
from typing import List, Dict, Any, Optional
from glob import glob
import numpy as np
import gym
from textworld import EnvInfos
import textworld.gym

# %%
class CustomAgent():
    """ Template agent for the TextWorld competition. """

    def __init__(self, seed=1234) -> None:
        self._initialized = False
        self._epsiode_has_started = False
        self.seed = seed
        self.rng = np.random.RandomState(self.seed)

    def train(self) -> None:
        """ Tell the agent it is in training mode. """
        pass  # [You can insert code here.]

    def eval(self) -> None:
        """ Tell the agent it is in evaluation mode. """
        pass  # [You can insert code here.]

    @property
    def select_additional_infos(self) -> EnvInfos:
        """
        Returns what additional information should be made available at each game step.

        Requested information will be included within the `infos` dictionary
        passed to `CustomAgent.act()`. To request specific information, create a
        :py:class:`textworld.EnvInfos <textworld.envs.wrappers.filter.EnvInfos>`
        and set the appropriate attributes to `True`. The possible choices are:

        * `description`: text description of the current room, i.e. output of the `look` command;
        * `inventory`: text listing of the player's inventory, i.e. output of the `inventory` command;
        * `max_score`: maximum reachable score of the game;
        * `objective`: objective of the game described in text;
        * `entities`: names of all entities in the game;
        * `verbs`: verbs understood by the the game;
        * `command_templates`: templates for commands understood by the the game;
        * `admissible_commands`: all commands relevant to the current state;

        In addition to the standard information, game specific information
        can be requested by appending corresponding strings to the `extras`
        attribute. For this competition, the possible extras are:

        * `'recipe'`: description of the cookbook;
        * `'walkthrough'`: one possible solution to the game (not guaranteed to be optimal);

        Example:
            Here is an example of how to request information and retrieve it.

            >>> from textworld import EnvInfos
            >>> request_infos = EnvInfos(description=True, inventory=True, extras=["recipe"])
            ...
            >>> env = gym.make(env_id)
            >>> ob, infos = env.reset()
            >>> print(infos["description"])
            >>> print(infos["inventory"])
            >>> print(infos["extra.recipe"])

        Notes:
            The following information *won't* be available at test time:

            * 'walkthrough'

            Requesting additional infos comes with some penalty (called handicap).
            The exact penalty values will be defined in function of the average
            scores achieved by agents using the same handicap.

            Handicap is defined as follows
                max_score, has_won, has_lost,               # Handicap 0
                description, inventory, verbs, objective,   # Handicap 1
                command_templates,                          # Handicap 2
                entities,                                   # Handicap 3
                extras=["recipe"],                          # Handicap 4
                admissible_commands,                        # Handicap 5
        """
        request_infos = EnvInfos()
        request_infos.admissible_commands = True
        request_infos.max_score = True 
        return request_infos

    def _init(self) -> None:
        """ Initialize the agent. """
        self._initialized = True

        # [You can insert code here.]

    def _start_episode(self, obs: List[str], infos: Dict[str, List[Any]]) -> None:
        """
        Prepare the agent for the upcoming episode.

        Arguments:
            obs: Initial feedback for each game.
            infos: Additional information for each game.
        """
        if not self._initialized:
            self._init()

        self._epsiode_has_started = True

        # [You can insert code here.]

    def _end_episode(self, obs: List[str], scores: List[int], infos: Dict[str, List[Any]]) -> None:
        """
        Tell the agent the episode has terminated.

        Arguments:
            obs: Previous command's feedback for each game.
            score: The score obtained so far for each game.
            infos: Additional information for each game.
        """
        self._epsiode_has_started = False

        # [You can insert code here.]

    def act(self, obs: List[str], scores: List[int], dones: List[bool], 
            infos: Dict[str, List[Any]]) -> Optional[List[str]]:
        """
        Acts upon the current list of observations.

        One text command must be returned for each observation.

        Arguments:
            obs: Previous command's feedback for each game.
            scores: The score obtained so far for each game.
            dones: Whether a game is finished.
            infos: Additional information for each game.

        Returns:
            Text commands to be performed (one per observation).
            If episode had ended (e.g. `all(dones)`), the returned
            value is ignored.

        Notes:
            Commands returned for games marked as `done` have no effect.
            The states for finished games are simply copy over until all
            games are done.
        """
        #if all(dones):
        #   self._end_episode(obs, scores, infos)
        #    return  # Nothing to return.

        if not self._epsiode_has_started:
            self._start_episode(obs, infos)

        # [Insert your code here to obtain the commands.]
        return self.rng.choice(infos["admissible_commands"])

# %%
gamefiles = []
GAMES_PATH = "./sample_games/"
for file in os.listdir(GAMES_PATH):
    if file.endswith('.ulx'):
        gamefiles.append(GAMES_PATH + file)

# %%
def play(agent, path, max_step=50, nb_episodes=10, verbose=True):
    request_infos = agent.select_additional_infos
    request_infos.max_score = True  # Needed to normalize the scores.

    gamefiles = [path]
    if os.path.isdir(path):
        gamefiles = glob(os.path.join(path, "*.ulx"))

    env_id = textworld.gym.register_games(gamefiles,
                                          request_infos=request_infos,
                                          max_episode_steps=max_step)
    env = gym.make(env_id)  # Create a Gym environment to play the text game.
    if verbose:
        if os.path.isdir(path):
            print(os.path.dirname(path), end="")
        else:
            print(os.path.basename(path), end="")

    # Collect some statistics: nb_steps, final reward.
    avg_moves, avg_scores, avg_norm_scores = [], [], []
    for no_episode in range(nb_episodes):
        obs, infos = env.reset()  # Start new episode.

        score = 0
        done = False
        nb_moves = 0
        while not done:
            command = agent.act(obs, score, done, infos)
            obs, score, done, infos = env.step(command)
            nb_moves += 1

        # Let the agent know the game is done.
        agent.act(obs, score, done, infos)

        if verbose:
            print(".", end="")
        avg_moves.append(nb_moves)
        avg_scores.append(score)
        avg_norm_scores.append(score / infos["max_score"])

    env.close()
    msg = "  \tavg. steps: {:5.1f}; avg. score: {:4.1f} / {}."
    if verbose:
        if os.path.isdir(path):
            print(msg.format(np.mean(avg_moves), np.mean(avg_norm_scores), 1))
        else:
            print(msg.format(np.mean(avg_moves), np.mean(
                avg_scores), infos["max_score"]))

# %%
for path in gamefiles:
   play(CustomAgent(), path)
# Out:
# tw-cooking-recipe3+cook+cut-2057SPdQu0mWiv0k.ulx..........  	avg. steps:  22.9; avg. score:  0.1 / 6.
# tw-cooking-recipe3+cook+cut+drop+go12-B10qS58OTbe0T8Qk.ulx..........  	avg. steps:  26.3; avg. score:  0.0 / 5.
# tw-cooking-recipe3+take3+cook+cut+go6-JeXVc8mBhgk8Sq9M.ulx..........  	avg. steps:  40.9; avg. score:  1.1 / 10.
# tw-cooking-recipe3+take3+cook+cut+go9-D397IBQkHe9Ws6ka.ulx..........  	avg. steps:  37.5; avg. score:  0.7 / 5.
# tw-cooking-recipe3+cook+cut+drop-3bVKf5jgiQypF2Kp.ulx..........  	avg. steps:  13.4; avg. score:  0.3 / 7.
# tw-cooking-recipe1+take1-11Oeig8bSVdGSp78.ulx..........  	avg. steps:  34.0; avg. score:  1.2 / 3.
# tw-cooking-recipe3+take3+cook+cut+drop-vNZGCrQVhoJdt7Nx.ulx..........  	avg. steps:  34.6; avg. score:  1.8 / 10.
# tw-cooking-recipe3-aXjNc96rIaD9Fk93.ulx..........  	avg. steps:  12.8; avg. score:  0.0 / 2.
# tw-cooking-recipe2+take2+cut+open-BnYEixa9iJKmFZxO.ulx..........  	avg. steps:  37.7; avg. score:  1.2 / 6.
# tw-cooking-recipe3+take3+cook+cut+open+drop+go12-jEKRfojdFqNVTXXK.ulx..........  	avg. steps:  45.7; avg. score:  0.3 / 10.

# %%
def play_render(agent,gamefile):
    requested_infos = agent.select_additional_infos
    env_id = textworld.gym.register_games([gamefile], requested_infos)

    agent = CustomAgent()

    env = gym.make(env_id)
    obs, infos = env.reset()

    env.render()  # Print the initial observation.

    score = 0
    done = False
    while not done:
        command = agent.act(obs,score,done,infos)
        ob, score, done, infos = env.step(command)
        env.render()

# %%
play_render(CustomAgent(), gamefiles[0])
# Out:
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# You are hungry! Let's cook a delicious meal. Check the cookbook in the kitchen
# for the recipe. Once done, enjoy your meal!
#
# -= Kitchen =-
# You arrive in a kitchen. An ordinary kind of place. The room seems oddly
# familiar, as though it were only superficially different from the other rooms in
# the building.
#
# You lean against the wall, inadvertently pressing a secret button. The wall
# opens up to reveal a fridge. The fridge is empty, what a horrible day! You make
# out a closed oven. You lean against the wall, inadvertently pressing a secret
# button. The wall opens up to reveal a table. You see a cookbook on the table.
# Now that's what I call TextWorld! What's that over there? It looks like it's a
# counter. You see a red apple and a knife on the counter. You make out a stove.
# But the thing hasn't got anything on it.
#
# > take cookbook from table
# You take the cookbook from the table.
#
# > examine fridge
# The fridge looks noble. It is open.
#
# > put cookbook on table
# You put the cookbook on the table.
#
# > drop yellow bell pepper
# You drop the yellow bell pepper on the ground.
#
# > insert purple potato into fridge
# You put the purple potato into the fridge.
#
# > examine purple potato
# The raw purple potato looks appealing.
#
# > look
# -= Kitchen =-
# You arrive in a kitchen. An ordinary kind of place. The room seems oddly
# familiar, as though it were only superficially different from the other rooms in
# the building.
#
# You lean against the wall, inadvertently pressing a secret button. The wall
# opens up to reveal a fridge. The fridge contains a raw purple potato. You make
# out a closed oven. You lean against the wall, inadvertently pressing a secret
# button. The wall opens up to reveal a table. You see a cookbook on the table.
# Now that's what I call TextWorld! What's that over there? It looks like it's a
# counter. You see a red apple and a knife on the counter. You make out a stove.
# But the thing hasn't got anything on it.
#
#
#
# There is a yellow bell pepper on the floor.
#
# > put block of cheese on stove
# You put the block of cheese on the stove.
#
# > take red apple from counter
# You take the red apple from the counter.
#
# > put yellow potato on counter
# You put the yellow potato on the counter.
#
# > put red apple on table
# You put the red apple on the table.
#
# > take knife from counter
# You take the knife from the counter.
#
# > take cookbook from table
# You take the cookbook from the table.
#
# > drop parsley
# You drop the parsley on the ground.
#
# > look
# -= Kitchen =-
# You arrive in a kitchen. An ordinary kind of place. The room seems oddly
# familiar, as though it were only superficially different from the other rooms in
# the building.
#
# You lean against the wall, inadvertently pressing a secret button. The wall
# opens up to reveal a fridge. The fridge contains a raw purple potato. You make
# out a closed oven. You lean against the wall, inadvertently pressing a secret
# button. The wall opens up to reveal a table. You see a red apple on the table.
# Now that's what I call TextWorld! What's that over there? It looks like it's a
# counter. You see a raw yellow potato on the counter. You make out a stove. You
# see a block of cheese on the stove.
#
#
#
# There is a parsley and a yellow bell pepper on the floor.
#
# > examine red apple
# That's a red apple!
#
# > put knife on table
# You put the knife on the table.
#
# > look
# -= Kitchen =-
# You arrive in a kitchen. An ordinary kind of place. The room seems oddly
# familiar, as though it were only superficially different from the other rooms in
# the building.
#
# You lean against the wall, inadvertently pressing a secret button. The wall
# opens up to reveal a fridge. The fridge contains a raw purple potato. You make
# out a closed oven. You lean against the wall, inadvertently pressing a secret
# button. The wall opens up to reveal a table. You see a knife and a red apple on
# the table. Now that's what I call TextWorld! What's that over there? It looks
# like it's a counter. You see a raw yellow potato on the counter. You make out a
# stove. You see a block of cheese on the stove.
#
#
#
# There is a parsley and a yellow bell pepper on the floor.
#
# > put cookbook on table
# You put the cookbook on the table.
#
# > take cookbook from table
# You take the cookbook from the table.
#
# > examine yellow bell pepper
# That's a yellow bell pepper!
#
# > examine knife
# The knife is dirty.
#
# > examine block of cheese
# That's a block of cheese!
#
# > examine oven
# Useful for roasting things.
#
# > examine counter
# The counter is solid.
#
# On the counter is a raw yellow potato.
#
# > examine parsley
# The parsley looks heavenly.
#
# > examine table
# The table is durable.
#
# On the table are a knife and a red apple.
#
# > close fridge
# You close the fridge.
#
# > examine table
# The table is durable.
#
# On the table are a knife and a red apple.
#
# > examine yellow potato
# That's a raw yellow potato!
#
# > put cookbook on table
# You put the cookbook on the table.
#
# > examine fridge
# The fridge looks noble. It is closed.
#
# > examine counter
# The counter is solid.
#
# On the counter is a raw yellow potato.
#
# > take yellow bell pepper
# You pick up the yellow bell pepper from the ground.
#
# > examine stove
# Useful for frying things.
#
# On the stove is a block of cheese.
#
# > cook yellow bell pepper with stove
# You fried the yellow bell pepper.
#
# > examine red apple
# That's a red apple!
#
# > put yellow bell pepper on table
# You put the yellow bell pepper on the table.
#
# > examine yellow potato
# That's a raw yellow potato!
#
# > take parsley
# You pick up the parsley from the ground.
#
# > open fridge
# You open the fridge, revealing a raw purple potato.
#
# > put parsley on table
# You put the parsley on the table.
#
# > examine parsley
# The parsley looks heavenly.
#
# > examine stove
# Useful for frying things.
#
# On the stove is a block of cheese.
#
# > examine table
# The table is durable.
#
# On the table are a parsley, a fried yellow bell pepper, a cookbook, a knife and
# a red apple.
#
# > look
# -= Kitchen =-
# You arrive in a kitchen. An ordinary kind of place. The room seems oddly
# familiar, as though it were only superficially different from the other rooms in
# the building.
#
# You lean against the wall, inadvertently pressing a secret button. The wall
# opens up to reveal a fridge. The fridge contains a raw purple potato. You make
# out a closed oven. You lean against the wall, inadvertently pressing a secret
# button. The wall opens up to reveal a table. You see a parsley, a fried yellow
# bell pepper, a cookbook, a knife and a red apple on the table. Now that's what I
# call TextWorld! What's that over there? It looks like it's a counter. You see a
# raw yellow potato on the counter. You make out a stove. You see a block of
# cheese on the stove.
#
# > take knife from table
# You take the knife from the table.
#
# > take red apple from table
# You take the red apple from the table.
#
# > examine parsley
# The parsley looks heavenly.
#
# > take purple potato from fridge
# You take the purple potato from the fridge.
