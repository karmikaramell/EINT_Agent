# %%
import os
import re
import random
from typing import List, Dict, Any, Optional
from collections import defaultdict
from time import time
from glob import glob
import numpy as np
import gym
from textworld import EnvInfos
import textworld.gym
import spacy
import substring

# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load("en_core_web_lg")

#import torch

#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
gamefiles = []
GAMES_PATH = "./sample_games/"
for file in os.listdir(GAMES_PATH):
    if file.endswith('.ulx'):
        gamefiles.append(GAMES_PATH + file)

# %%
def play(agent, path, max_step=50, nb_episodes=10, verbose=True):
    request_infos = agent.select_additional_infos
    request_infos.max_score = True  # Needed to normalize the scores.

    gamefiles = [path]
    if os.path.isdir(path):
        gamefiles = glob(os.path.join(path, "*.ulx"))

    env_id = textworld.gym.register_games(gamefiles,
                                          request_infos=request_infos,
                                          max_episode_steps=max_step)
    env = gym.make(env_id)  # Create a Gym environment to play the text game.
    if verbose:
        if os.path.isdir(path):
            print(os.path.dirname(path), end="")
        else:
            print(os.path.basename(path), end="")

    # Collect some statistics: nb_steps, final reward.
    avg_moves, avg_scores, avg_norm_scores = [], [], []
    for no_episode in range(nb_episodes):
        obs, infos = env.reset()  # Start new episode.

        score = 0
        done = False
        nb_moves = 0
        while not done:
            command = agent.act(obs, score, done, infos)
            obs, score, done, infos = env.step(command)
            nb_moves += 1

        # Let the agent know the game is done.
        agent.act(obs, score, done, infos)

        if verbose:
            print(".", end="")
        avg_moves.append(nb_moves)
        avg_scores.append(score)
        avg_norm_scores.append(score / infos["max_score"])

    env.close()
    msg = "  \tavg. steps: {:5.1f}; avg. score: {:4.1f} / {}."
    if verbose:
        if os.path.isdir(path):
            print(msg.format(np.mean(avg_moves), np.mean(avg_norm_scores), 1))
        else:
            print(msg.format(np.mean(avg_moves), np.mean(
                avg_scores), infos["max_score"]))

# %%
class CustomAgent():
    
    def __init__(self) -> None:
        self._initialized = False
        self._epsiode_has_started = False
        self.mode = "test"
        self.command_history = []
        self.history_counter = 0
        
        # read in vocab.txt and map to id
        with open("./vocab.txt") as f:
            self.word_vocab = f.read().split("\n")
        self.word2id = {}
        self.id2word = []
        for i, w in enumerate(self.word_vocab):
            self.word2id[w] = i
            self.id2word.append(w)
        
        self.qvalues = [0] * len(self.id2word)

    def train(self) -> None:
        self.mode = "train"
        self.transitions = []
        self.last_score = 0
        self.no_train_step = 0
        self.moves = 0
        self.command_history = []
        self.history_counter = 0

    def test(self) -> None:
        self.mode = "test"

    @property
    def select_additional_infos(self) -> EnvInfos:
        """
        Returns what additional information should be made available at each game step.

        Requested information will be included within the `infos` dictionary
        passed to `CustomAgent.act()`. To request specific information, create a
        :py:class:`textworld.EnvInfos <textworld.envs.wrappers.filter.EnvInfos>`
        and set the appropriate attributes to `True`. The possible choices are:

        * `description`: text description of the current room, i.e. output of the `look` command;
        * `inventory`: text listing of the player's inventory, i.e. output of the `inventory` command;
        * `max_score`: maximum reachable score of the game;
        * `objective`: objective of the game described in text;
        * `entities`: names of all entities in the game;
        * `verbs`: verbs understood by the the game;
        * `command_templates`: templates for commands understood by the the game;
        * `admissible_commands`: all commands relevant to the current state;

        In addition to the standard information, game specific information
        can be requested by appending corresponding strings to the `extras`
        attribute. For this competition, the possible extras are:

        * `'recipe'`: description of the cookbook;
        * `'walkthrough'`: one possible solution to the game (not guaranteed to be optimal);

        Example:
            Here is an example of how to request information and retrieve it.

            >>> from textworld import EnvInfos
            >>> request_infos = EnvInfos(description=True, inventory=True, extras=["recipe"])
            ...
            >>> env = gym.make(env_id)
            >>> ob, infos = env.reset()
            >>> print(infos["description"])
            >>> print(infos["inventory"])
            >>> print(infos["extra.recipe"])

            Handicap is defined as follows
                max_score, has_won, has_lost,               # Handicap 0
                description, inventory, verbs, objective,   # Handicap 1
                command_templates,                          # Handicap 2
                entities,                                   # Handicap 3
                extras=["recipe"],                          # Handicap 4
                admissible_commands,                        # Handicap 5
        """
        
        return EnvInfos(description=True, inventory=False, verbs=True, extras=["recipe"], max_score = True, 
                        admissible_commands=False, has_won=True, has_lost=True)
      

    def _init(self) -> None:
        """ Initialize the agent. """
        self._initialized = True

        # [You can insert code here.]
    
    def _get_word_id(self, word):
        """
        look up id of a word in dictionary & add word to dictionaries if unknown.
        """
        if word not in self.word2id:        
            self.id2word.append(word)
            self.qvalues.append(0)
            self.word2id[word] = len(self.word2id)
        return self.word2id[word]

    
    def _get_word_by_id(self, id):
        """
        look up word by id in dictionary.
        returns None, if id does not exist.
        """
        if id < len(self.id2word):
            return self.id2word[id]
        else:
            return None
    
    def _get_qvalue(self, id):
        """
        Getter for qvalues (admissible commands with scores).
        """
        if id < len(self.qvalues):
            return self.qvalues[id]
        else:
            return None
    
    def _tokenize(self, text):
        """
        Simple tokenizer: strip out all non-alphabetic characters.
        """
        text = re.sub("[^a-zA-Z0-9\- ]", " ", text)
        word_ids = list(map(self._get_word_id, text.split()))
        return word_ids
    
    def _start_episode(self, obs: List[str], infos: Dict[str, List[Any]]) -> None:
        """
        Prepare the agent for the upcoming episode.
        Arguments:
            obs: Initial feedback for each game.
            infos: Additional information for each game.
        """
        if not self._initialized:
            self._init()

        self._epsiode_has_started = True

        # [You can insert code here.]

    def _end_episode(self, obs: List[str], scores: List[int], infos: Dict[str, List[Any]]) -> None:
        """
        Tell the agent the episode has terminated.
        Arguments:
            obs: Previous command's feedback for each game.
            score: The score obtained so far for each game.
            infos: Additional information for each game.
        """
        self._epsiode_has_started = False

        # [You can insert code here.]
    
    def update_qvalues(self, command : List[int],reward):
        """
        Updates admissible commands with additionally rewards.
        """
        for id in command:
            self.qvalues[id] += reward
    
    def calc_avg_qvalue(self, command) -> int:
        """
        Gets the average of all qvalues as a sum.
        """
        sum = 0
        for id in command:
            sum += self._get_qvalue(id)
        sum = sum/ len(command)
        return sum

    def choose_best_cmd(self,commands) -> int:
        """
        Gets randomly one of the best rewarded admissible commands.
        """
        avg_qvalues =  []
        for cmd in commands:
            avg_qvalues.append(self.calc_avg_qvalue(cmd))
        max_value = max(avg_qvalues)
        max_commands = []
        for i in range(len(commands)):
            if(max_value == avg_qvalues[i]):
                max_commands.append(i)
        return random.choice(max_commands)
    
    def get_alternative_cmd(self, commands) -> int:
        """
        Idea of an alternative command, if the current is used in the last 3 commands.
        Chooses the second best command.
        """
        avg_qvalues =  []
        for cmd in commands:
            avg_qvalues.append(self.calc_avg_qvalue(cmd))
     
        first_max = max(avg_qvalues[0],avg_qvalues[1]) 
        second_max = min(avg_qvalues[0],avg_qvalues[1]) 

        for i in range(2,len(avg_qvalues)): 
            if avg_qvalues[i] > first_max: 
                second_max = first_max
                first_max=avg_qvalues[i] 
            else: 
                if avg_qvalues[i]>second_max: 
                    second_max=avg_qvalues[i] 
        return avg_qvalues.index(second_max)   
    
    def check_last_3_usages(self, cmds, infos, action):
        """
        building a historylist of commands to get out of a loop of death o_o
        """
        if self.command_history is not None:
            last_commands = self.command_history[-3:]
            
        # compare-counters for comparing actions from the 3 last moves.
        if self.history_counter > self.moves:
            same_command_in_list = True 
            counter_use_same_command = 0
            """ 
            If the current admissible command (action) is one of the last 3 commands, the while-loop
            will be skipped. 
            If the same random chosen command is going 2 times through the while-loop, after tahat, the loops
            will be skipped, too.
            """
            while same_command_in_list is True and counter_use_same_command < 3:
                try:
                    if last_commands.index(action):
                        best_index = self.get_alternative_cmd(cmds)
                        action = infos[best_index]
                        counter_use_same_command += 1
                    else:
                        same_command_in_list = False
                except ValueError:
                    same_command_in_list = False
                    print("last_commands List does not contain value")
                    
        # adds valid action to the command-history
        self.command_history.append(action)
        return last_commands

    def get_nouns_from_description(self, descr):
        """
        Get all nouns from description for finding admissible commands.
        """
        descr_nlp = nlp(descr)
        noun_list = []
        last_word_list = []
        sentences = descr.split(".")
        adm_objs = []
        
        # get the last word of a sentence from descr. because they can be significant.
        # reason: some words will not be found by nlp.
        # puts them in a list
        for sentence in sentences:
            last_word_list.append(sentence.split(" ")[-1]) 
            
        # get all nouns from the description with nlp. also not neccessary nouns.
        for chunk in descr_nlp.noun_chunks:
            if chunk is not None:
                noun_list.append(chunk.root.text)

        # compares last words of a list with all nouns in description, relevant words will be saved in a list
        for word in last_word_list:
            if word in noun_list:
                adm_objs.append(word)
        adm_objs.remove('TextWorld') # need better solution
        adm_objs.remove('it') # need better solution
        print("adm_objs: ", adm_objs)
                    
        return adm_objs

    def get_nouns_from_recipe(self, recipe):
        """
        Get all nouns from recipe for finding admissible commands.
        """
        rec = recipe.replace("\n", " ")
        rec = rec.split(":")
        
        recipe_nlp = nlp(rec[2]) # get relevant nouns
        noun_list = []
        #for chunk in recipe_nlp.ent:
        for chunk in recipe_nlp.noun_chunks:
            if chunk is not None:
                noun_list.append(chunk.text)
        noun_list = noun_list[:-1] # drops meal 
        
        return noun_list
    
    def create_all_possible_commands(self, similiar_list, nouns_list):
        """
        Try to create possible commands. 
        Missing commands like '...into frigde...'
        open fridge, close fridge
        go east, go west, go north, go south
        take knife, drop knife
        put ... into ..., put ... on ..., take ... from ...
        """
        # without recipe but description, can be filtered out of the text. but this is another task
        commands = ['open fridge', 'close fridge', 'take knife', 'drop knife']
        #commands = []
        for verb in similiar_list:
            for noun in nouns_list:
                #cmd = verb.lemma_ + " " + noun
                cmd = verb + " " + noun
                if cmd not in commands:
                    commands.append(cmd)
        #print("created adm cmds: ", commands)
        return commands
    
    def create_adm_cmds(self, nouns_list, descr, poss_cmds):
        """
        Try to create admissible commands. 
        """
        adm_cmds = []
        for noun in nouns_list:
            if descr.find(noun) >= -1:
                for cmd in poss_cmds:
                    if noun in cmd:
                        adm_cmds.append(cmd)
        #print("adm_cmds: ", adm_cmds)
        return adm_cmds

    def act(self, obs: str, score: int, done: bool, 
            infos: Dict[str, List[Any]]) -> Optional[List[str]]:
        """
        Acts upon the current list of observations.

        One text command must be returned for each observation.

        Arguments:
            obs: Previous command's feedback for each game.
            scores: The score obtained so far for each game.
            dones: Whether a game is finished.
            infos: Additional information for each game.

        Returns:
            Text commands to be performed (one per observation).
            If episode had ended (e.g. `all(dones)`), the returned
            value is ignored.

        Notes:
            Commands returned for games marked as `done` have no effect.
            The states for finished games are simply copy over until all
            games are done.
        """
        #if all(dones):
        #   self._end_episode(obs, scores, infos)
        #    return  # Nothing to return.

        if not self._epsiode_has_started:
            self._start_episode(obs, infos)
        
        #print("descr.: ", infos["description"])
        descr = infos["description"]
        verbs = infos["verbs"]
        stopverbs = ["examine", "look"] # drop examine and look from adm_cmds
        new_verbs = [word for word in verbs if word not in stopverbs]
        print(new_verbs)
        recipe = infos["extra.recipe"]
       
        # creating adm cmds from recipe and description
        nouns_list = self.get_nouns_from_recipe(recipe)
        poss_cmds = self.create_all_possible_commands(new_verbs, nouns_list)
        adm_cmds = self.create_adm_cmds(nouns_list, descr, poss_cmds)
        
        # creating adm cmds only from descr, the results make me cry.
#         nouns_list = self.get_nouns_from_recipe(recipe)
#         adm_nouns = self.get_nouns_from_description(infos["description"])
#         nouns_list.extend(adm_nouns) # all important nouns together

        
#         poss_cmds = self.create_all_possible_commands(new_verbs, nouns_list)
#         adm_cmds = self.create_adm_cmds(nouns_list, descr, poss_cmds)
        
        #choose best command based on "qvalues"
        cmds = []
        for i in range(len(adm_cmds)):
            cmds.append(self._tokenize(adm_cmds[i]))
        best_index = self.choose_best_cmd(cmds)
        action = adm_cmds[best_index]
        
        
        # last_commands for debug information and find new action if one is used the last 3 times.
        last_commands = self.check_last_3_usages(cmds, adm_cmds, action)
        
        if self.mode == "test":
            return action
        
        #train mode, counter update
        self.no_train_step += 1 
        reward = 0
        self.moves += 1
        self.history_counter += 1
        
        #calculate rewards
        if self.transitions:
            reward = score - self.last_score
            self.last_score = score
            if infos["has_won"]:
                reward += 10
            if infos["has_lost"]:
                reward -= 10
            if reward == 0:
                reward -= 1
            self.update_qvalues(self.transitions[-1],reward)

        # Debug output
        if(self.no_train_step % 1 == 0):
            print("")
            #print(infos["admissible_commands"])
            #print(infos["extra.recipe"]) # type string
            print("Last 3 admissible commands: ", last_commands)
            print("train step:" + str(self.no_train_step))
            print("last reward:" + str(reward))
            print("obs in act: " + obs)
            command = "last command: "
            if self.transitions:
                for id in self.transitions[-1]:
                    command += " " + self._get_word_by_id(id)
                print(command)
        
        #save last command
        self.transitions.append(cmds[best_index])
        
        if done:
            if(infos["has_won"]):
                print("-------- WON GAME ----------")
            else:
                print("-------- LOST GAME ----------")
            print(" ")
            self.last_score = 0
            self.moves = 0
            self.transitions = []
            self.command_history = []
            
        return action

# %%
agent = CustomAgent()
agent.train()
starttime = time()
for i in range(5):
    print("-------------------------------------")
    print("GAME: " + str(i+1))
    print("-------------------------------------")
    play(agent, gamefiles[5])
print("Trained in {:.2f} secs".format(time() - starttime))
# Out:
# -------------------------------------
# GAME: 1
# -------------------------------------
# tw-cooking-recipe3+take3+cook+cut+drop-vNZGCrQVhoJdt7Nx.ulx['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  []
# train step:1
# last reward:0
# obs in act:
#
#
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# You are hungry! Let's cook a delicious meal. Check the cookbook in the kitchen for the recipe. Once done, enjoy your meal!
#
# -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a red apple, a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
#
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['chop table']
# train step:2
# last reward:-1
# obs in act: (with the table)
# Can only cut cuttable food.
#
#
# last command:  chop table
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['chop table', 'open pepper']
# train step:3
# last reward:-1
# obs in act: Which do you mean, the red hot pepper, the orange bell pepper or the yellow bell pepper?
#
# last command:  open pepper
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['chop table', 'open pepper', 'take pepper']
# train step:4
# last reward:-1
# obs in act: Which do you mean, the red hot pepper, the orange bell pepper or the yellow bell pepper?
#
# last command:  take pepper
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['open pepper', 'take pepper', 'lock the red apple']
# train step:5
# last reward:-1
# obs in act: (with the red apple)
# You need to take the red apple first.
#
#
# last command:  lock the red apple
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['take pepper', 'lock the red apple', 'put the red apple']
# train step:6
# last reward:-1
# obs in act: (in the red apple)
# You need to take the red apple first.
#
#
# last command:  put the red apple
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['lock the red apple', 'put the red apple', 'inventory fridge']
# train step:7
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory fridge
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['put the red apple', 'inventory fridge', 'cook fridge']
# train step:8
# last reward:-1
# obs in act: (with the fridge)
# The fridge is fixed in place.
#
#
# last command:  cook fridge
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['inventory fridge', 'cook fridge', 'dice stove']
# train step:9
# last reward:-1
# obs in act: (with the stove)
# Can only cut cuttable food.
#
#
# last command:  dice stove
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['cook fridge', 'dice stove', 'unlock stove']
# train step:10
# last reward:-1
# obs in act: (with the stove)
# The stove is fixed in place.
#
#
# last command:  unlock stove
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['dice stove', 'unlock stove', 'close oven']
# train step:11
# last reward:-1
# obs in act: That's already closed.
#
#
# last command:  close oven
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['unlock stove', 'close oven', 'go counter']
# train step:12
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go counter
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['close oven', 'go counter', 'prepare knife']
# train step:13
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare knife
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['go counter', 'prepare knife', 'slice cookbook']
# train step:14
# last reward:-1
# obs in act: (with the cookbook)
# Can only cut cuttable food.
#
#
# last command:  slice cookbook
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['prepare knife', 'slice cookbook', 'drop cookbook']
# train step:15
# last reward:-1
# obs in act: You haven't got that.
#
#
# last command:  drop cookbook
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['slice cookbook', 'drop cookbook', 'insert counter']
# train step:16
# last reward:-1
# obs in act: (in the counter)
# The counter is fixed in place.
#
#
# last command:  insert counter
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['drop cookbook', 'insert counter', 'eat the yellow potato']
# train step:17
# last reward:-1
# obs in act: You should cook the yellow potato first.
#
#
# last command:  eat the yellow potato
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['insert counter', 'eat the yellow potato', 'drink knife']
# train step:18
# last reward:-1
# obs in act: You need to take the knife first.
#
#
# last command:  drink knife
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['eat the yellow potato', 'drink knife', 'drink table']
# train step:19
# last reward:-1
# obs in act: The table is fixed in place.
#
#
# last command:  drink table
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['drink knife', 'drink table', 'take oven']
# train step:20
# last reward:-1
# obs in act: That's fixed in place.
#
#
#
# last command:  take oven
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['drink table', 'take oven', 'slice oven']
# train step:21
# last reward:-1
# obs in act: (with the oven)
# Can only cut cuttable food.
#
#
# last command:  slice oven
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['take oven', 'slice oven', 'go cookbook']
# train step:22
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go cookbook
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['slice oven', 'go cookbook', 'inventory fridge']
# train step:23
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory fridge
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['go cookbook', 'inventory fridge', 'drop knife']
# train step:24
# last reward:-1
# obs in act: You haven't got that.
#
#
# last command:  drop knife
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['inventory fridge', 'drop knife', 'chop table']
# train step:25
# last reward:-1
# obs in act: (with the table)
# Can only cut cuttable food.
#
#
# last command:  chop table
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['drop knife', 'chop table', 'open stove']
# train step:26
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open stove
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['chop table', 'open stove', 'eat the red onion']
# train step:27
# last reward:-1
# obs in act: You need to take the red onion first.
#
#
# last command:  eat the red onion
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['open stove', 'eat the red onion', 'put pepper']
# train step:28
# last reward:-1
# obs in act: Which do you mean, the red hot pepper, the orange bell pepper or the yellow bell pepper?
#
# last command:  put pepper
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['eat the red onion', 'put pepper', 'prepare pepper']
# train step:29
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare pepper
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['put pepper', 'prepare pepper', 'prepare counter']
# train step:30
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare counter
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['prepare pepper', 'prepare counter', 'dice counter']
# train step:31
# last reward:-1
# obs in act: (with the counter)
# Can only cut cuttable food.
#
#
# last command:  dice counter
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['prepare counter', 'dice counter', 'insert the yellow potato']
# train step:32
# last reward:-1
# obs in act: (in the yellow potato)
# You need to take the yellow potato first.
#
#
# last command:  insert the yellow potato
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['dice counter', 'insert the yellow potato', 'close the yellow potato']
# train step:33
# last reward:-1
# obs in act: It isn't something you can close.
#
#
# last command:  close the yellow potato
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['insert the yellow potato', 'close the yellow potato', 'cook stove']
# train step:34
# last reward:-1
# obs in act: (with the stove)
# The stove is fixed in place.
#
#
# last command:  cook stove
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['close the yellow potato', 'cook stove', 'lock table']
# train step:35
# last reward:-1
# obs in act: (with the table)
# The table is fixed in place.
#
#
# last command:  lock table
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['cook stove', 'lock table', 'unlock fridge']
# train step:36
# last reward:-1
# obs in act: (with the fridge)
# The fridge is fixed in place.
#
#
# last command:  unlock fridge
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['lock table', 'unlock fridge', 'unlock oven']
# train step:37
# last reward:-1
# obs in act: (with the oven)
# The oven is fixed in place.
#
#
# last command:  unlock oven
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['unlock fridge', 'unlock oven', 'drink cookbook']
# train step:38
# last reward:-1
# obs in act: You need to take the cookbook first.
#
#
# last command:  drink cookbook
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['unlock oven', 'drink cookbook', 'open cookbook']
# train step:39
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open cookbook
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['drink cookbook', 'open cookbook', 'open knife']
# train step:40
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open knife
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['open cookbook', 'open knife', 'dice knife']
# train step:41
# last reward:-1
# obs in act: (with the knife)
# Can only cut cuttable food.
#
#
# last command:  dice knife
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['open knife', 'dice knife', 'go oven']
# train step:42
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go oven
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['dice knife', 'go oven', 'drop stove']
# train step:43
# last reward:-1
# obs in act: The stove is already here.
#
#
# last command:  drop stove
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['go oven', 'drop stove', 'insert the red onion']
# train step:44
# last reward:-1
# obs in act: (in the red onion)
# You need to take the red onion first.
#
#
# last command:  insert the red onion
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['drop stove', 'insert the red onion', 'put fridge']
# train step:45
# last reward:-1
# obs in act: (in the fridge)
# The fridge is fixed in place.
#
#
# last command:  put fridge
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['insert the red onion', 'put fridge', 'take table']
# train step:46
# last reward:-1
# obs in act: That's fixed in place.
#
#
#
# last command:  take table
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['put fridge', 'take table', 'close counter']
# train step:47
# last reward:-1
# obs in act: It isn't something you can close.
#
#
# last command:  close counter
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['take table', 'close counter', 'lock pepper']
# train step:48
# last reward:-1
# obs in act: Which do you mean, the red hot pepper, the orange bell pepper or the yellow bell pepper?
#
# last command:  lock pepper
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['close counter', 'lock pepper', 'inventory pepper']
# train step:49
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory pepper
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['lock pepper', 'inventory pepper', 'cook fridge']
# train step:50
# last reward:-1
# obs in act: (with the fridge)
# The fridge is fixed in place.
#
#
# last command:  cook fridge
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['inventory pepper', 'cook fridge', 'chop knife']
# train step:51
# last reward:-1
# obs in act: (with the knife)
# Can only cut cuttable food.
#
#
# last command:  chop knife
# -------- LOST GAME ----------
#
# .['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  []
# train step:52
# last reward:0
# obs in act:
#
#
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# You are hungry! Let's cook a delicious meal. Check the cookbook in the kitchen for the recipe. Once done, enjoy your meal!
#
# -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a red apple, a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
#
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['slice cookbook']
# train step:53
# last reward:-1
# obs in act: (with the cookbook)
# Can only cut cuttable food.
#
#
# last command:  slice cookbook
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['slice cookbook', 'eat stove']
# train step:54
# last reward:-1
# obs in act: That's plainly inedible.
#
#
# last command:  eat stove
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['slice cookbook', 'eat stove', 'eat oven']
# train step:55
# last reward:-1
# obs in act: That's plainly inedible.
#
#
# last command:  eat oven
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['eat stove', 'eat oven', 'take the yellow potato']
# train step:56
# last reward:1
# obs in act: You take the yellow potato from the counter.
#
#
#
# Your score has just gone up by one point.
#
# last command:  take the yellow potato
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['eat oven', 'take the yellow potato', 'chop the red apple']
# train step:57
# last reward:-1
# obs in act: (with the red apple)
# Cutting something requires a knife.
#
#
# last command:  chop the red apple
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
#
# Last 3 admissible commands:  ['take the yellow potato', 'chop the red apple', 'take the yellow potato']
# train step:58
# last reward:-1
# obs in act: You already have that.
#
#
#
# last command:  take the yellow potato
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['chop the red apple', 'take the yellow potato', 'take the yellow potato']
# train step:59
# last reward:-1
# obs in act: You already have that.
#
#
#
# last command:  take the yellow potato
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['take the yellow potato', 'take the yellow potato', 'dice table']
# train step:60
# last reward:-1
# obs in act: (with the table)
# Can only cut cuttable food.
#
#
# last command:  dice table
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['take the yellow potato', 'dice table', 'drop table']
# train step:61
# last reward:-1
# obs in act: The table is already here.
#
#
# last command:  drop table
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['dice table', 'drop table', 'go counter']
# train step:62
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go counter
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drop table', 'go counter', 'put counter']
# train step:63
# last reward:-1
# obs in act: (in the counter)
# The counter is fixed in place.
#
#
# last command:  put counter
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['go counter', 'put counter', 'slice cookbook']
# train step:64
# last reward:-1
# obs in act: (with the cookbook)
# Can only cut cuttable food.
#
#
# last command:  slice cookbook
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['put counter', 'slice cookbook', 'lock knife']
# train step:65
# last reward:-1
# obs in act: (with the yellow potato)
# That doesn't seem to be something you can lock.
#
#
# last command:  lock knife
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['slice cookbook', 'lock knife', 'unlock fridge']
# train step:66
# last reward:-1
# obs in act: (with the yellow potato)
# That's unlocked at the moment.
#
#
# last command:  unlock fridge
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['lock knife', 'unlock fridge', 'prepare oven']
# train step:67
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare oven
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['unlock fridge', 'prepare oven', 'inventory stove']
# train step:68
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory stove
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# ...
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drink pepper', 'open fridge', 'eat fridge']
# train step:2431
# last reward:-1
# obs in act: That's plainly inedible.
#
#
# last command:  eat fridge
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['open fridge', 'eat fridge', 'dice cookbook']
# train step:2432
# last reward:-1
# obs in act: (with the cookbook)
# Can only cut cuttable food.
#
#
# last command:  dice cookbook
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['eat fridge', 'dice cookbook', 'cook cookbook']
# train step:2433
# last reward:-1
# obs in act: (with the cookbook)
# Can only cut cuttable food.
#
#
# last command:  dice cookbook
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['dice cookbook', 'cook cookbook', 'cook the red onion']
# train step:2434
# last reward:-1
# obs in act: (with the red onion)
# You need to take the red onion first.
#
#
# last command:  cook the red onion
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['cook cookbook', 'cook the red onion', 'inventory the red onion']
# train step:2435
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory the red onion
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['cook the red onion', 'inventory the red onion', 'drop stove']
# train step:2436
# last reward:-1
# obs in act: The stove is already here.
#
#
# last command:  drop stove
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['inventory the red onion', 'drop stove', 'drop table']
# train step:2437
# last reward:-1
# obs in act: The table is already here.
#
#
# last command:  drop table
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drop stove', 'drop table', 'inventory pepper']
# train step:2438
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory pepper
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drop table', 'inventory pepper', 'slice pepper']
# train step:2439
# last reward:-1
# obs in act: Which do you mean, the red hot pepper, the orange bell pepper or the yellow bell pepper?
#
# last command:  slice pepper
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['inventory pepper', 'slice pepper', 'take oven']
# train step:2440
# last reward:-1
# obs in act: That's fixed in place.
#
#
#
# last command:  take oven
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['slice pepper', 'take oven', 'open oven']
# train step:2441
# last reward:-1
# obs in act: You open the oven.
#
#
# last command:  open oven
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['take oven', 'open oven', 'open knife']
# train step:2442
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open knife
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['open oven', 'open knife', 'cook knife']
# train step:2443
# last reward:-1
# obs in act: (with the knife)
# You need to take the knife first.
#
#
# last command:  cook knife
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['open knife', 'cook knife', 'prepare knife']
# train step:2444
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare knife
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['cook knife', 'prepare knife', 'go counter']
# train step:2445
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go counter
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['prepare knife', 'go counter', 'go the yellow potato']
# train step:2446
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go the yellow potato
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['go counter', 'go the yellow potato', 'close the yellow potato']
# train step:2447
# last reward:-1
# obs in act: It isn't something you can close.
#
#
# last command:  close the yellow potato
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['go the yellow potato', 'close the yellow potato', 'close cookbook']
# train step:2448
# last reward:-1
# obs in act: It isn't something you can close.
#
#
# last command:  close cookbook
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['close the yellow potato', 'close cookbook', 'drink stove']
# train step:2449
# last reward:-1
# obs in act: The stove is fixed in place.
#
#
# last command:  drink stove
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['close cookbook', 'drink stove', 'insert stove']
# train step:2450
# last reward:-1
# obs in act: (in the stove)
# The stove is fixed in place.
#
#
# last command:  insert stove
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drink stove', 'insert stove', 'eat table']
# train step:2451
# last reward:-1
# obs in act: That's plainly inedible.
#
#
# last command:  eat table
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['insert stove', 'eat table', 'chop table']
# train step:2452
# last reward:-1
# obs in act: (with the table)
# Can only cut cuttable food.
#
#
# last command:  chop table
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['eat table', 'chop table', 'unlock fridge']
# train step:2453
# last reward:-1
# obs in act: (with the fridge)
# The fridge is fixed in place.
#
#
# last command:  unlock fridge
# ['chop', 'close', 'cook', 'dice', 'drink', 'drop', 'eat', 'go', 'insert', 'inventory', 'lock', 'open', 'prepare', 'put', 'slice', 'take', 'unlock']
# adm_objs:  ['fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# concatenated nounlist:  ['the red apple', 'the red apple', 'the red onion', 'the yellow potato', 'the yellow potato', 'fridge', 'pepper', 'oven', 'table', 'cookbook', 'counter', 'knife', 'stove']
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['chop table', 'unlock fridge', 'chop fridge']
# train step:2454
# last reward:-1
# obs in act: (with the fridge)
# The fridge is fixed in place.
#
#
# last command:  unlock fridge
# -------- LOST GAME ----------
#
# .  	avg. steps:  50.0; avg. score:  0.2 / 10.
# Trained in 169.77 secs

# %%
agent.test()
play(agent, gamefiles[5])
# Out:
# tw-cooking-recipe3+take3+cook+cut+drop-vNZGCrQVhoJdt7Nx.ulxdescr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a red apple, a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# apple dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a red apple, a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# apple dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# chop dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# .descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# ...
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
# There is a red apple on the floor.
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
# There is a red apple on the floor.
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# descr.:  -= Kitchen =-
# You've seen better kitchens, but at least this one seems pretty ordinary.
#
# You see a fridge. The fridge contains a red onion, a raw pork chop, a red hot pepper, a white onion, a carrot and an orange bell pepper. You can see a closed oven. You make out a table. The table is massive. On the table you can see a cookbook. You can see a counter. The counter is vast. On the counter you can see a raw yellow potato, a banana, a raw red potato, a yellow bell pepper, a raw purple potato and a knife. Classic TextWorld. You rest your hand against a wall, but you miss the wall and fall onto a stove. The stove is conventional. However, the stove, like an empty stove, has nothing on it. Sometimes, just sometimes, TextWorld can just be the worst.
#
#
#
# There is a red apple on the floor.
#
#
# kitchen dobj
# fridge dobj
# onion dobj
# oven dobj
# table dobj
# cookbook dobj
# counter dobj
# potato dobj
# hand dobj
# wall dobj
# nothing dobj
# last_commands List does not contain value
# .  	avg. steps:  50.0; avg. score:  1.6 / 10.

# %%
for i in range(len(agent.qvalues)):
    if(agent.qvalues[i] != 0 ):
        print(agent._get_word_by_id(i) + " : " + str(agent.qvalues[i]))
# Out:
# apple : -656
# chop : -120
# close : -120
# cook : -120
# dice : -121
# drink : -120
# drop : -121
# eat : -127
# examine : -120
# go : -120
# insert : -121
# inventory : -120
# lock : -120
# look : -121
# onion : -656
# open : -120
# potato : -983
# prepare : -120
# put : -121
# red : -1312
# slice : -121
# take : -122
# the : -2295
# unlock : -120
# yellow : -983

# %%
agent.train()
starttime = time()
for i in range(5):
    print("-------------------------------------")
    print("GAME: " + str(i+1))
    print("-------------------------------------")
    play(agent, gamefiles[8])
print("Trained in {:.2f} secs".format(time() - starttime))
# Out:
# -------------------------------------
# GAME: 1
# -------------------------------------
# tw-cooking-recipe3+cook+cut+drop+go12-B10qS58OTbe0T8Qk.ulxdescr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
#
# Last 3 admissible commands:  []
# train step:1
# last reward:0
# obs in act:
#
#
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# You are hungry! Let's cook a delicious meal. Check the cookbook in the kitchen for the recipe. Once done, enjoy your meal!
#
# -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
#
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
#
# Last 3 admissible commands:  ['put the red hot pepper']
# train step:2
# last reward:-1
# obs in act: (in the red hot pepper)
# You can't put something inside itself.
#
#
# last command:  put the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['put the red hot pepper', 'drop the red hot pepper']
# train step:3
# last reward:-1
# obs in act: You drop the red hot pepper on the ground.
#
#
# last command:  drop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['put the red hot pepper', 'drop the red hot pepper', 'take the red hot pepper']
# train step:4
# last reward:-1
# obs in act: You're carrying too many things already.
#
#
#
# last command:  take the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['drop the red hot pepper', 'take the red hot pepper', 'inventory the red hot pepper']
# train step:5
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['take the red hot pepper', 'inventory the red hot pepper', 'cook the red hot pepper']
# train step:6
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  cook the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['inventory the red hot pepper', 'cook the red hot pepper', 'cook the red hot pepper']
# train step:7
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  cook the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['cook the red hot pepper', 'cook the red hot pepper', 'unlock the red hot pepper']
# train step:8
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  unlock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['cook the red hot pepper', 'unlock the red hot pepper', 'unlock the red hot pepper']
# train step:9
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  unlock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['unlock the red hot pepper', 'unlock the red hot pepper', 'prepare the red hot pepper']
# train step:10
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['unlock the red hot pepper', 'prepare the red hot pepper', 'open the red hot pepper']
# train step:11
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['prepare the red hot pepper', 'open the red hot pepper', 'open the red hot pepper']
# train step:12
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['open the red hot pepper', 'open the red hot pepper', 'chop the red hot pepper']
# train step:13
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  chop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['open the red hot pepper', 'chop the red hot pepper', 'chop the red hot pepper']
# train step:14
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  chop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['chop the red hot pepper', 'chop the red hot pepper', 'prepare the red hot pepper']
# train step:15
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['chop the red hot pepper', 'prepare the red hot pepper', 'go the red hot pepper']
# train step:16
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['prepare the red hot pepper', 'go the red hot pepper', 'go the red hot pepper']
# train step:17
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['go the red hot pepper', 'go the red hot pepper', 'close the red hot pepper']
# train step:18
# last reward:-1
# obs in act: It isn't something you can close.
#
#
# last command:  close the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['go the red hot pepper', 'close the red hot pepper', 'dice the red hot pepper']
# train step:19
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  dice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['close the red hot pepper', 'dice the red hot pepper', 'take the red hot pepper']
# train step:20
# last reward:-1
# obs in act: You're carrying too many things already.
#
#
#
# last command:  take the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['dice the red hot pepper', 'take the red hot pepper', 'eat the red hot pepper']
# train step:21
# last reward:-1
# obs in act: You need to take the red hot pepper first.
#
#
# last command:  eat the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['take the red hot pepper', 'eat the red hot pepper', 'eat the red hot pepper']
# train step:22
# last reward:-1
# obs in act: You need to take the red hot pepper first.
#
#
# last command:  eat the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['eat the red hot pepper', 'eat the red hot pepper', 'drop the red hot pepper']
# train step:23
# last reward:-1
# obs in act: The red hot pepper is already here.
#
#
# last command:  drop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['eat the red hot pepper', 'drop the red hot pepper', 'lock the red hot pepper']
# train step:24
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  lock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['drop the red hot pepper', 'lock the red hot pepper', 'put the red hot pepper']
# train step:25
# last reward:-1
# obs in act: (in the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  put the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['lock the red hot pepper', 'put the red hot pepper', 'inventory the red hot pepper']
# train step:26
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['put the red hot pepper', 'inventory the red hot pepper', 'inventory the red hot pepper']
# train step:27
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['inventory the red hot pepper', 'inventory the red hot pepper', 'drink the red hot pepper']
# train step:28
# last reward:-1
# obs in act: You need to take the red hot pepper first.
#
#
# last command:  drink the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['inventory the red hot pepper', 'drink the red hot pepper', 'slice the red hot pepper']
# train step:29
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  slice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['drink the red hot pepper', 'slice the red hot pepper', 'insert the red hot pepper']
# train step:30
# last reward:-1
# obs in act: (in the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  insert the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['slice the red hot pepper', 'insert the red hot pepper', 'insert the red hot pepper']
# train step:31
# last reward:-1
# obs in act: (in the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  insert the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['insert the red hot pepper', 'insert the red hot pepper', 'chop the red hot pepper']
# train step:32
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  chop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['insert the red hot pepper', 'chop the red hot pepper', 'put the red hot pepper']
# train step:33
# last reward:-1
# obs in act: (in the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  put the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['chop the red hot pepper', 'put the red hot pepper', 'put the red hot pepper']
# train step:34
# last reward:-1
# obs in act: (in the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  put the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['put the red hot pepper', 'put the red hot pepper', 'lock the red hot pepper']
# train step:35
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  lock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['put the red hot pepper', 'lock the red hot pepper', 'unlock the red hot pepper']
# train step:36
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  unlock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['lock the red hot pepper', 'unlock the red hot pepper', 'slice the red hot pepper']
# train step:37
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  slice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['unlock the red hot pepper', 'slice the red hot pepper', 'cook the red hot pepper']
# train step:38
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  cook the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['slice the red hot pepper', 'cook the red hot pepper', 'cook the red hot pepper']
# train step:39
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  cook the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['cook the red hot pepper', 'cook the red hot pepper', 'open the red hot pepper']
# train step:40
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['cook the red hot pepper', 'open the red hot pepper', 'close the red hot pepper']
# train step:41
# last reward:-1
# obs in act: It isn't something you can close.
#
#
# last command:  close the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['open the red hot pepper', 'close the red hot pepper', 'drop the red hot pepper']
# train step:42
# last reward:-1
# obs in act: The red hot pepper is already here.
#
#
# last command:  drop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['close the red hot pepper', 'drop the red hot pepper', 'drop the red hot pepper']
# train step:43
# last reward:-1
# obs in act: The red hot pepper is already here.
#
#
# last command:  drop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['drop the red hot pepper', 'drop the red hot pepper', 'dice the red hot pepper']
# train step:44
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  dice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['drop the red hot pepper', 'dice the red hot pepper', 'dice the red hot pepper']
# train step:45
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  dice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['dice the red hot pepper', 'dice the red hot pepper', 'prepare the red hot pepper']
# train step:46
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['dice the red hot pepper', 'prepare the red hot pepper', 'drink the red hot pepper']
# train step:47
# last reward:-1
# obs in act: You need to take the red hot pepper first.
#
#
# last command:  drink the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['prepare the red hot pepper', 'drink the red hot pepper', 'drink the red hot pepper']
# train step:48
# last reward:-1
# obs in act: You need to take the red hot pepper first.
#
#
# last command:  drink the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['drink the red hot pepper', 'drink the red hot pepper', 'take the red hot pepper']
# train step:49
# last reward:-1
# obs in act: You're carrying too many things already.
#
#
#
# last command:  take the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['drink the red hot pepper', 'take the red hot pepper', 'take the red hot pepper']
# train step:50
# last reward:-1
# obs in act: You're carrying too many things already.
#
#
#
# last command:  take the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
# Last 3 admissible commands:  ['take the red hot pepper', 'take the red hot pepper', 'go the red hot pepper']
# train step:51
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go the red hot pepper
# -------- LOST GAME ----------
#
# .descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  []
# train step:52
# last reward:0
# obs in act:
#
#
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# You are hungry! Let's cook a delicious meal. Check the cookbook in the kitchen for the recipe. Once done, enjoy your meal!
#
# -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
#
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['inventory the red hot pepper']
# train step:53
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['inventory the red hot pepper', 'lock the red hot pepper']
# train step:54
# last reward:-1
# obs in act: (with the red hot pepper)
# That doesn't seem to be something you can lock.
#
#
# last command:  lock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['inventory the red hot pepper', 'lock the red hot pepper', 'unlock the red hot pepper']
# train step:55
# last reward:-1
# obs in act: (with the red hot pepper)
# That doesn't seem to be something you can unlock.
#
#
# last command:  unlock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['lock the red hot pepper', 'unlock the red hot pepper', 'close the red hot pepper']
# train step:56
# last reward:-1
# obs in act: It isn't something you can close.
#
#
# last command:  close the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['unlock the red hot pepper', 'close the red hot pepper', 'insert the red hot pepper']
# train step:57
# last reward:-1
# obs in act: (in the red hot pepper)
# You can't put something inside itself.
#
#
# last command:  insert the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['close the red hot pepper', 'insert the red hot pepper', 'prepare the red hot pepper']
# train step:58
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['insert the red hot pepper', 'prepare the red hot pepper', 'eat the red hot pepper']
# train step:59
# last reward:-10
# obs in act: You eat the red hot pepper. Not bad.
#
#
#                               *** You lost! ***
#
# You scored 0 out of a possible 5, in 6 turn(s).
#
#
# Would you like to QUIT?
# >
# last command:  eat the red hot pepper
# -------- LOST GAME ----------
#
# .descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  []
# train step:60
# last reward:0
# obs in act:
#
#
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# You are hungry! Let's cook a delicious meal. Check the cookbook in the kitchen for the recipe. Once done, enjoy your meal!
#
# -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
#
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
#
# Last 3 admissible commands:  ['open the red hot pepper']
# train step:61
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['open the red hot pepper', 'open the red hot pepper']
# train step:62
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['open the red hot pepper', 'open the red hot pepper', 'slice the red hot pepper']
# train step:63
# last reward:-1
# obs in act: What do you want to slice the red hot pepper with?
#
# last command:  slice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['open the red hot pepper', 'slice the red hot pepper', 'chop the red hot pepper']
# train step:64
# last reward:-1
# obs in act: What do you want to slice the red hot pepper with?
#
# last command:  slice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
#
# Last 3 admissible commands:  ['slice the red hot pepper', 'chop the red hot pepper', 'close the red hot pepper']
# train step:65
# last reward:-1
# obs in act: What do you want to chop the red hot pepper with?
#
# last command:  chop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['chop the red hot pepper', 'close the red hot pepper', 'close the red hot pepper']
# train step:66
# last reward:-1
# obs in act: What do you want to chop the red hot pepper with?
#
# last command:  chop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['close the red hot pepper', 'close the red hot pepper', 'put the red hot pepper']
# train step:67
# last reward:-1
# obs in act: (in the red hot pepper)
# You can't put something inside itself.
#
#
# last command:  put the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['close the red hot pepper', 'put the red hot pepper', 'take the red hot pepper']
# train step:68
# last reward:-1
# obs in act: You already have that.
#
#
#
# last command:  take the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['put the red hot pepper', 'take the red hot pepper', 'inventory the red hot pepper']
# train step:69
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['take the red hot pepper', 'inventory the red hot pepper', 'close the red hot pepper']
# train step:70
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['inventory the red hot pepper', 'close the red hot pepper', 'go the red hot pepper']
# train step:71
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['close the red hot pepper', 'go the red hot pepper', 'prepare the red hot pepper']
# train step:72
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['go the red hot pepper', 'prepare the red hot pepper', 'lock the red hot pepper']
# train step:73
# last reward:-1
# obs in act: (with the red hot pepper)
# That doesn't seem to be something you can lock.
#
#
# last command:  lock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['prepare the red hot pepper', 'lock the red hot pepper', 'insert the red hot pepper']
# train step:74
# last reward:-1
# obs in act: (in the red hot pepper)
# You can't put something inside itself.
#
#
# last command:  insert the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['lock the red hot pepper', 'insert the red hot pepper', 'cook the red hot pepper']
# train step:75
# last reward:-1
# obs in act: What do you want to cook the red hot pepper with?
#
# last command:  cook the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['insert the red hot pepper', 'cook the red hot pepper', 'close the red hot pepper']
# train step:76
# last reward:-1
# obs in act: It isn't something you can close.
#
#
# last command:  close the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['cook the red hot pepper', 'close the red hot pepper', 'dice the red hot pepper']
# train step:77
# last reward:-1
# obs in act: What do you want to dice the red hot pepper with?
#
# last command:  dice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['close the red hot pepper', 'dice the red hot pepper', 'drop the red hot pepper']
# train step:78
# last reward:-1
# obs in act: You drop the red hot pepper on the ground.
#
#
# last command:  drop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['dice the red hot pepper', 'drop the red hot pepper', 'drink the red hot pepper']
# train step:79
# last reward:-1
# obs in act: You need to take the red hot pepper first.
#
#
# last command:  drink the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drop the red hot pepper', 'drink the red hot pepper', 'unlock the red hot pepper']
# train step:80
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  unlock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drink the red hot pepper', 'unlock the red hot pepper', 'chop the red hot pepper']
# train step:81
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  unlock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['unlock the red hot pepper', 'chop the red hot pepper', 'slice the red hot pepper']
# train step:82
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  slice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['chop the red hot pepper', 'slice the red hot pepper', 'cook the red hot pepper']
# train step:83
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  cook the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['slice the red hot pepper', 'cook the red hot pepper', 'go the red hot pepper']
# train step:84
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['cook the red hot pepper', 'go the red hot pepper', 'chop the red hot pepper']
# train step:85
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  chop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['go the red hot pepper', 'chop the red hot pepper', 'chop the red hot pepper']
# train step:86
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  chop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['chop the red hot pepper', 'chop the red hot pepper', 'close the red hot pepper']
# train step:87
# last reward:-1
# obs in act: It isn't something you can close.
#
#
# last command:  close the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['chop the red hot pepper', 'close the red hot pepper', 'dice the red hot pepper']
# train step:88
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  dice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['close the red hot pepper', 'dice the red hot pepper', 'prepare the red hot pepper']
# train step:89
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['dice the red hot pepper', 'prepare the red hot pepper', 'put the red hot pepper']
# train step:90
# last reward:-1
# obs in act: (in the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  put the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['prepare the red hot pepper', 'put the red hot pepper', 'open the red hot pepper']
# train step:91
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['put the red hot pepper', 'open the red hot pepper', 'drop the red hot pepper']
# train step:92
# last reward:-1
# obs in act: The red hot pepper is already here.
#
#
# last command:  drop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['open the red hot pepper', 'drop the red hot pepper', 'take the red hot pepper']
# train step:93
# last reward:-1
# obs in act: You're carrying too many things already.
#
#
#
# last command:  take the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drop the red hot pepper', 'take the red hot pepper', 'drink the red hot pepper']
# train step:94
# last reward:-1
# obs in act: You need to take the red hot pepper first.
#
#
# last command:  drink the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['take the red hot pepper', 'drink the red hot pepper', 'insert the red hot pepper']
# train step:95
# last reward:-1
# obs in act: (in the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  insert the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drink the red hot pepper', 'insert the red hot pepper', 'lock the red hot pepper']
# train step:96
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  lock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['insert the red hot pepper', 'lock the red hot pepper', 'close the red hot pepper']
# train step:97
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  lock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['lock the red hot pepper', 'close the red hot pepper', 'inventory the red hot pepper']
# train step:98
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['close the red hot pepper', 'inventory the red hot pepper', 'drop the red hot pepper']
# train step:99
# last reward:-1
# obs in act: The red hot pepper is already here.
#
#
# last command:  drop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['inventory the red hot pepper', 'drop the red hot pepper', 'unlock the red hot pepper']
# train step:100
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  unlock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drop the red hot pepper', 'unlock the red hot pepper', 'open the red hot pepper']
# train step:101
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['unlock the red hot pepper', 'open the red hot pepper', 'insert the red hot pepper']
# train step:102
# last reward:-1
# obs in act: (in the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  insert the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['open the red hot pepper', 'insert the red hot pepper', 'slice the red hot pepper']
# train step:103
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  slice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['insert the red hot pepper', 'slice the red hot pepper', 'take the red hot pepper']
# train step:104
# last reward:-1
# obs in act: You're carrying too many things already.
#
#
#
# last command:  take the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['slice the red hot pepper', 'take the red hot pepper', 'close the red hot pepper']
# train step:105
# last reward:-1
# obs in act: It isn't something you can close.
#
#
# last command:  close the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['take the red hot pepper', 'close the red hot pepper', 'drink the red hot pepper']
# train step:106
# last reward:-1
# obs in act: You need to take the red hot pepper first.
#
#
# last command:  drink the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['close the red hot pepper', 'drink the red hot pepper', 'go the red hot pepper']
# train step:107
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drink the red hot pepper', 'go the red hot pepper', 'dice the red hot pepper']
# train step:108
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  dice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['go the red hot pepper', 'dice the red hot pepper', 'prepare the red hot pepper']
# train step:109
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['dice the red hot pepper', 'prepare the red hot pepper', 'put the red hot pepper']
# train step:110
# last reward:-1
# obs in act: (in the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  put the red hot pepper
# -------- LOST GAME ----------
#
# .descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  []
# train step:111
# last reward:0
# obs in act:
#
#
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
# ...
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['dice the yellow potato', 'slice the red hot pepper', 'cook the red hot pepper']
# train step:2139
# last reward:-1
# obs in act: What do you want to cook the red hot pepper with?
#
# last command:  cook the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['slice the red hot pepper', 'cook the red hot pepper', 'drink the red hot pepper']
# train step:2140
# last reward:-1
# obs in act: You cannot drink the red hot pepper.
#
#
# last command:  drink the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['cook the red hot pepper', 'drink the red hot pepper', 'inventory the yellow potato']
# train step:2141
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drink the red hot pepper', 'inventory the yellow potato', 'put the yellow potato']
# train step:2142
# last reward:-1
# obs in act: (in the yellow potato)
# You can't put something inside itself.
#
#
# last command:  put the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['inventory the yellow potato', 'put the yellow potato', 'lock the yellow potato']
# train step:2143
# last reward:-1
# obs in act: (with the yellow potato)
# That doesn't seem to be something you can lock.
#
#
# last command:  lock the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['put the yellow potato', 'lock the yellow potato', 'drop the red hot pepper']
# train step:2144
# last reward:-1
# obs in act: You drop the red hot pepper on the ground.
#
#
# last command:  drop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['lock the yellow potato', 'drop the red hot pepper', 'eat the red hot pepper']
# train step:2145
# last reward:-1
# obs in act: You need to take the red hot pepper first.
#
#
# last command:  eat the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drop the red hot pepper', 'eat the red hot pepper', 'insert the red hot pepper']
# train step:2146
# last reward:-1
# obs in act: (in the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  insert the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['eat the red hot pepper', 'insert the red hot pepper', 'insert the yellow potato']
# train step:2147
# last reward:-1
# obs in act: (in the yellow potato)
# You can't put something inside itself.
#
#
# last command:  insert the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['insert the red hot pepper', 'insert the yellow potato', 'drop the yellow potato']
# train step:2148
# last reward:-1
# obs in act: You drop the yellow potato on the ground.
#
#
# last command:  drop the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['insert the yellow potato', 'drop the yellow potato', 'prepare the yellow potato']
# train step:2149
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drop the yellow potato', 'prepare the yellow potato', 'chop the red hot pepper']
# train step:2150
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  chop the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['prepare the yellow potato', 'chop the red hot pepper', 'close the red hot pepper']
# train step:2151
# last reward:-1
# obs in act: It isn't something you can close.
#
#
# last command:  close the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['chop the red hot pepper', 'close the red hot pepper', 'put the red hot pepper']
# train step:2152
# last reward:-1
# obs in act: (in the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  put the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['close the red hot pepper', 'put the red hot pepper', 'eat the yellow potato']
# train step:2153
# last reward:-1
# obs in act: You should cook the yellow potato first.
#
#
# last command:  eat the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['put the red hot pepper', 'eat the yellow potato', 'open the yellow potato']
# train step:2154
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['eat the yellow potato', 'open the yellow potato', 'cook the yellow potato']
# train step:2155
# last reward:-1
# obs in act: It isn't something you can open.
#
#
# last command:  open the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['open the yellow potato', 'cook the yellow potato', 'drink the red hot pepper']
# train step:2156
# last reward:-1
# obs in act: You need to take the red hot pepper first.
#
#
# last command:  drink the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['cook the yellow potato', 'drink the red hot pepper', 'dice the red hot pepper']
# train step:2157
# last reward:-1
# obs in act: (with the red hot pepper)
# Cutting something requires a knife.
#
#
# last command:  dice the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['drink the red hot pepper', 'dice the red hot pepper', 'lock the red hot pepper']
# train step:2158
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  lock the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['dice the red hot pepper', 'lock the red hot pepper', 'inventory the yellow potato']
# train step:2159
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['lock the red hot pepper', 'inventory the yellow potato', 'cook the yellow potato']
# train step:2160
# last reward:-1
# obs in act: I only understood you as far as wanting to take inventory.
#
# last command:  inventory the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['inventory the yellow potato', 'cook the yellow potato', 'slice the yellow potato']
# train step:2161
# last reward:-1
# obs in act: (with the yellow potato)
# Cutting something requires a knife.
#
#
# last command:  slice the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['cook the yellow potato', 'slice the yellow potato', 'cook the red hot pepper']
# train step:2162
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  cook the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['slice the yellow potato', 'cook the red hot pepper', 'take the red hot pepper']
# train step:2163
# last reward:-1
# obs in act: You're carrying too many things already.
#
#
#
# last command:  take the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['cook the red hot pepper', 'take the red hot pepper', 'go the red hot pepper']
# train step:2164
# last reward:-1
# obs in act: You're carrying too many things already.
#
#
#
# last command:  take the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
#
# Last 3 admissible commands:  ['take the red hot pepper', 'go the red hot pepper', 'go the yellow potato']
# train step:2165
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['go the red hot pepper', 'go the yellow potato', 'go the yellow potato']
# train step:2166
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['go the yellow potato', 'go the yellow potato', 'chop the yellow potato']
# train step:2167
# last reward:-1
# obs in act: That's not something you can enter.
#
#
# last command:  go the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['go the yellow potato', 'chop the yellow potato', 'prepare the red hot pepper']
# train step:2168
# last reward:-1
# obs in act: I didn't understand that sentence.
#
# last command:  prepare the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['chop the yellow potato', 'prepare the red hot pepper', 'close the red hot pepper']
# train step:2169
# last reward:-1
# obs in act: It isn't something you can close.
#
#
# last command:  close the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['prepare the red hot pepper', 'close the red hot pepper', 'eat the red hot pepper']
# train step:2170
# last reward:-1
# obs in act: You need to take the red hot pepper first.
#
#
# last command:  eat the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['close the red hot pepper', 'eat the red hot pepper', 'lock the yellow potato']
# train step:2171
# last reward:-1
# obs in act: (with the yellow potato)
# You need to take the yellow potato first.
#
#
# last command:  lock the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['eat the red hot pepper', 'lock the yellow potato', 'slice the yellow potato']
# train step:2172
# last reward:-1
# obs in act: (with the yellow potato)
# Cutting something requires a knife.
#
#
# last command:  slice the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['lock the yellow potato', 'slice the yellow potato', 'chop the yellow potato']
# train step:2173
# last reward:-1
# obs in act: (with the yellow potato)
# Cutting something requires a knife.
#
#
# last command:  chop the yellow potato
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
#
#
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['slice the yellow potato', 'chop the yellow potato', 'drink the red hot pepper']
# train step:2174
# last reward:-1
# obs in act: You need to take the red hot pepper first.
#
#
# last command:  drink the red hot pepper
# descr.:  -= Garden =-
# Well, here we are in a garden.
#
#
#
# There is an exit to the south.
#
# There is a raw yellow potato and a red hot pepper on the floor.
# last_commands List does not contain value
#
# Last 3 admissible commands:  ['chop the yellow potato', 'drink the red hot pepper', 'unlock the red hot pepper']
# train step:2175
# last reward:-1
# obs in act: (with the red hot pepper)
# You need to take the red hot pepper first.
#
#
# last command:  unlock the red hot pepper
# -------- LOST GAME ----------
#
# .  	avg. steps:  42.6; avg. score:  0.0 / 5.
# Trained in 53.26 secs

# %%
# versuche
wordids = agent._tokenize("cook a meal")
print(wordids)

print(agent._get_word_id("cook"))
print(agent._get_word_by_id(4664))
# Out:
# [4664, 785, 11449]
# 4664
# cook

# %%
def play_render(agent,gamefile):
    requested_infos = agent.select_additional_infos
    env_id = textworld.gym.register_games([gamefile], requested_infos)

    env = gym.make(env_id)
    obs, infos = env.reset()

    env.render()  # Print the initial observation.

    score = 0
    done = False
    while not done:
        command = agent.act(obs,score,done,infos)
        ob, score, done, infos = env.step(command)
        env.render()

# %%
agent.test()
play_render(agent, gamefiles[5])
# Out:
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# You are hungry! Let's cook a delicious meal. Check the cookbook in the kitchen
# for the recipe. Once done, enjoy your meal!
#
# -= Kitchen =-
# You're now in the kitchen. I guess you better just go and list everything you
# see here.
#
# You hear a noise behind you and spin around, but you can't see anything other
# than a fridge. The fridge is empty! This is the worst thing that could possibly
# happen, ever! You see a closed oven. You make out a table. The table is massive.
# On the table you can make out a cookbook. You can make out a counter. The
# counter is vast. On the counter you can make out a sliced fried red hot pepper,
# a red apple, a yellow bell pepper and a knife. You smell an intriguing smell,
# and follow it to a stove. You shudder, but continue examining the stove. But the
# thing is empty, unfortunately. Hm. Oh well
#
# > take red hot pepper from counter
# You take the red hot pepper from the counter.
#
#
#
# Your score has just gone up by one point.
#
# > prepare meal
# Adding the meal to your inventory.
#
#
#
# Your score has just gone up by one point.
#
# > eat meal
# You eat the meal. Not bad.
#
#
# Your score has just gone up by one point.
#
#
#                                *** The End ***
#
# You scored 3 out of a possible 3, in 5 turn(s).
#
#
# Would you like to QUIT?
# >
