# %%
import os
import re
import random
from typing import List, Dict, Any, Optional
from collections import defaultdict
from time import time
from glob import glob
import numpy as np
import gym
from textworld import EnvInfos
import textworld.gym

# for text similarity
import spacy
import wmd
import en_core_web_md

#import torch

#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
gamefiles = []
GAMES_PATH = "./sample_games/"
for file in os.listdir(GAMES_PATH):
    if file.endswith('.ulx'):
        gamefiles.append(GAMES_PATH + file)

# %% [markdown]
# ## Play Function
# - create gym environment to let the agent play textworld

# %%
def play(agent, path, max_step=50, nb_episodes=10, verbose=True):
    request_infos = agent.select_additional_infos
    request_infos.max_score = True  # Needed to normalize the scores.

    gamefiles = [path]
    if os.path.isdir(path):
        gamefiles = glob(os.path.join(path, "*.ulx"))

    env_id = textworld.gym.register_games(gamefiles,
                                          request_infos=request_infos,
                                          max_episode_steps=max_step)
    env = gym.make(env_id)  # Create a Gym environment to play the text game.
    if verbose:
        if os.path.isdir(path):
            print(os.path.dirname(path), end="")
        else:
            print(os.path.basename(path), end="")

    # Collect some statistics: nb_steps, final reward.
    avg_moves, avg_scores, avg_norm_scores = [], [], []
    for no_episode in range(nb_episodes):
        obs, infos = env.reset()  # Start new episode.

        score = 0
        done = False
        nb_moves = 0
        while not done:
            # the agent chooses an action
            command = agent.act(obs, score, done, infos)
            # carry out action and update parameters
            obs, score, done, infos = env.step(command)
            nb_moves += 1

        # Let the agent know the game is done.
        agent.act(obs, score, done, infos)

        if verbose:
            print(".", end="")
        avg_moves.append(nb_moves)
        avg_scores.append(score)
        avg_norm_scores.append(score / infos["max_score"])

    env.close()
    msg = "  \tavg. steps: {:5.1f}; avg. score: {:4.1f} / {}."
    if verbose:
        if os.path.isdir(path):
            print(msg.format(np.mean(avg_moves), np.mean(avg_norm_scores), 1))
        else:
            print(msg.format(np.mean(avg_moves), np.mean(
                avg_scores), infos["max_score"]))

# %%
nlp = en_core_web_md.load()
nlp.add_pipe(wmd.WMD.SpacySimilarityHook(nlp), last=True)

# %% [markdown]
# ## Custom Agent
# - uses Handicap 5 (admissible commands from EnvInfos)
# - saves a "qvalue" for each word in vocab.txt
# - admissible commands get ranked by the average qvalue of their words
# - "qvalues" get updated while the agent is playing depending on scores
#     - calculate the reward by subtracting last round's score from this round's score
#     - if the command led to a win reward each word an extra +10
#     - if the command led to a defeat reward each word an extra -10
#     - if the command did not get any reward, add a penalty of -1 (necessary to avoid using the same command over and over again)

# %%
class CustomAgent():
    
    def __init__(self) -> None:
        self._initialized = False
        self._epsiode_has_started = False
        self.mode = "test"
        self.command_history = []
        self.history_counter = 0
        self.nlp = nlp
        
        # read in vocab.txt and map to id
        with open("./vocab.txt") as f:
            self.word_vocab = f.read().split("\n")
        self.word2id = {} #dictionary for converting words to ids
        self.id2word = [] #list for converting ids to words
        for i, w in enumerate(self.word_vocab):
            self.word2id[w] = i
            self.id2word.append(w)
        
        self.qvalues = [0] * len(self.id2word) #rewards for words

    def train(self) -> None:
        self.mode = "train"
        self.transitions = []
        self.last_score = 0
        self.no_train_step = 0
        self.moves = 0
        self.command_history = []
        self.history_counter = 0

    def test(self) -> None:
        self.mode = "test"

    @property
    def select_additional_infos(self) -> EnvInfos:
        """
        Returns what additional information should be made available at each game step.

        Requested information will be included within the `infos` dictionary
        passed to `CustomAgent.act()`. To request specific information, create a
        :py:class:`textworld.EnvInfos <textworld.envs.wrappers.filter.EnvInfos>`
        and set the appropriate attributes to `True`. The possible choices are:

        * `description`: text description of the current room, i.e. output of the `look` command;
        * `inventory`: text listing of the player's inventory, i.e. output of the `inventory` command;
        * `max_score`: maximum reachable score of the game;
        * `objective`: objective of the game described in text;
        * `entities`: names of all entities in the game;
        * `verbs`: verbs understood by the the game;
        * `command_templates`: templates for commands understood by the the game;
        * `admissible_commands`: all commands relevant to the current state;

        In addition to the standard information, game specific information
        can be requested by appending corresponding strings to the `extras`
        attribute. For this competition, the possible extras are:

        * `'recipe'`: description of the cookbook;
        * `'walkthrough'`: one possible solution to the game (not guaranteed to be optimal);

        Example:
            Here is an example of how to request information and retrieve it.

            >>> from textworld import EnvInfos
            >>> request_infos = EnvInfos(description=True, inventory=True, extras=["recipe"])
            ...
            >>> env = gym.make(env_id)
            >>> ob, infos = env.reset()
            >>> print(infos["description"])
            >>> print(infos["inventory"])
            >>> print(infos["extra.recipe"])

            Handicap is defined as follows
                max_score, has_won, has_lost,               # Handicap 0
                description, inventory, verbs, objective,   # Handicap 1
                command_templates,                          # Handicap 2
                entities,                                   # Handicap 3
                extras=["recipe"],                          # Handicap 4
                admissible_commands,                        # Handicap 5
        """
        return EnvInfos(description=True, inventory=True, max_score = True, 
                        admissible_commands=True, has_won=True, has_lost=True, extras=["recipe"])

    def _init(self) -> None:
        """ Initialize the agent. """
        self._initialized = True

        # [You can insert code here.]
    
    def _get_word_id(self, word):
        """
        look up id of a word in dictionary & add word to dictionaries if unknown.
        """
        if word not in self.word2id:        
            self.id2word.append(word)
            self.qvalues.append(0)
            self.word2id[word] = len(self.word2id)
        return self.word2id[word]

    
    def _get_word_by_id(self, id):
        """
        look up word by id in dictionary.
        returns None, if id does not exist.
        """
        if id < len(self.id2word):
            return self.id2word[id]
        else:
            return None
    
    def _get_qvalue(self, id):
        """
        Getter for qvalues (words with scores).
        """
        if id < len(self.qvalues):
            return self.qvalues[id]
        else:
            return None
    
    def _tokenize(self, text):
        """
        Simple tokenizer: strip out all non-alphabetic characters.
        """
        text = re.sub("[^a-zA-Z0-9\- ]", " ", text)
        word_ids = list(map(self._get_word_id, text.split()))
        return word_ids
    
    def _start_episode(self, obs: List[str], infos: Dict[str, List[Any]]) -> None:
        """
        Prepare the agent for the upcoming episode.
        Arguments:
            obs: Initial feedback for each game.
            infos: Additional information for each game.
        """
        if not self._initialized:
            self._init()

        self._epsiode_has_started = True

        # [You can insert code here.]

    def _end_episode(self, obs: List[str], scores: List[int], infos: Dict[str, List[Any]]) -> None:
        """
        Tell the agent the episode has terminated.
        Arguments:
            obs: Previous command's feedback for each game.
            score: The score obtained so far for each game.
            infos: Additional information for each game.
        """
        self._epsiode_has_started = False

        # [You can insert code here.]
    
    def tok_to_nlp(self, tok1: List[int]):
        """ convert list of word ids into nlp string"""
        text = ""
        for id in tok1:
            text += self._get_word_by_id(id) + " "
        text = self.nlp(text)
        return text
    
    def calc_similarity(self, tok1: List[int], tok2: List[int]) -> float:
        """calculate the similarity between two nlp strings"""
        text1 = self.tok_to_nlp(tok1)
        text2 = self.tok_to_nlp(tok2)
        sim = 0.0
        # sometimes error when cost is negative...
        try:
            # usually 0.0 is best, and the worst i got was about 9
            # so normalized by 10 and subtracted from 1 to get best at 1.0
            sim = 1-text1.similarity(text2)/10
        except:
            pass
        return sim
    
    def update_qvalues(self, command : List[int],reward):
        """
        Updates words with additional rewards.
        """
        for id in command:
            self.qvalues[id] += reward
    
    def calc_avg_qvalue(self, command) -> int:
        """
        Gets the average of all qvalues of words in a command as a sum.
        """
        sum = 0
        for id in command:
            sum += self._get_qvalue(id)
        sum = sum/ len(command)
        return sum

    def choose_best_cmd(self,commands, recipe_tok) -> int:
        """
        Gets randomly one of the best rewarded admissible commands.
        """
        avg_qvalues =  []
        for cmd in commands:
            qval = self.calc_avg_qvalue(cmd) + self.calc_similarity(cmd,recipe_tok)*10
            #print(str(self.tok_to_nlp(cmd)) + ": " +  str(self.calc_similarity(cmd,recipe_tok)))
            avg_qvalues.append(qval)
        max_value = max(avg_qvalues)
        max_commands = []
        for i in range(len(commands)):
            if(max_value == avg_qvalues[i]):
                max_commands.append(i)
        return random.choice(max_commands)
    
    def get_alternative_cmd(self, commands, recipe_tok) -> int:
        """
        Idea of an alternative command, if the current is used in the last 3 commands.
        Chooses the second best command.
        """
        avg_qvalues =  []
        for cmd in commands:
            qval = self.calc_avg_qvalue(cmd) + self.calc_similarity(cmd,recipe_tok)*10
            avg_qvalues.append(qval)
     
        first_max = max(avg_qvalues[0],avg_qvalues[1]) 
        second_max = min(avg_qvalues[0],avg_qvalues[1]) 

        for i in range(2,len(avg_qvalues)): 
            if avg_qvalues[i] > first_max: 
                second_max = first_max
                first_max=avg_qvalues[i] 
            else: 
                if avg_qvalues[i]>second_max: 
                    second_max=avg_qvalues[i] 

        #print("Second highest number is : ",str(second_max)) 
        return avg_qvalues.index(second_max)
        
                        
    def act(self, obs: str, score: int, done: bool, 
            infos: Dict[str, List[Any]]) -> Optional[List[str]]:
        """
        Acts upon the current list of observations.

        One text command must be returned for each observation.

        Arguments:
            obs: Previous command's feedback for each game.
            scores: The score obtained so far for each game.
            dones: Whether a game is finished.
            infos: Additional information for each game.

        Returns:
            Text commands to be performed (one per observation).
            If episode had ended (e.g. `all(dones)`), the returned
            value is ignored.

        Notes:
            Commands returned for games marked as `done` have no effect.
            The states for finished games are simply copy over until all
            games are done.
        """
        #print("obs in act: ", obs)
        #if all(dones):
        #   self._end_episode(obs, scores, infos)
        #    return  # Nothing to return.

        if not self._epsiode_has_started:
            self._start_episode(obs, infos)
        
        recipe = infos["extra.recipe"]
        #if self.moves == 0:
            #print(recipe)
        recipe_tok = self._tokenize(recipe)

        #choose best command based on "qvalues"
        cmds = []
        for i in range(len(infos["admissible_commands"])):
            cmds.append(self._tokenize(infos["admissible_commands"][i]))
        best_index = self.choose_best_cmd(cmds, recipe_tok)
        action = infos["admissible_commands"][best_index]
        
        #building a historylist of commands to get out of a loop of death o_o
        if self.command_history is not None:
            last_commands = self.command_history[-3:]
            
        # compare-counters for comparing actions from the 3 last moves.
        if self.history_counter > self.moves:
            same_command_in_list = True 
            counter_use_same_command = 0
            """ 
            If the current admissible command (action) is one of the last 3 commands, the while-loop
            will be skipped. 
            If the same random chosen command is going 2 times through the while-loop, after tahat, the loops
            will be skipped, too.
            """
            while same_command_in_list is True and counter_use_same_command < 3:
                try:
                    if last_commands.index(action):
                        #best_index = self.choose_best_cmd(cmds)
                        best_index = self.get_alternative_cmd(cmds,  recipe_tok)
                        action = infos["admissible_commands"][best_index]
                        counter_use_same_command += 1
                    else:
                        same_command_in_list = False
                except ValueError:
                    same_command_in_list = False
                    #print("last_commands List does not contain value")
        # adds valid action to the command-history
        self.command_history.append(action)
        
        if self.mode == "test":
            return action
        
        #train mode, counter update
        self.no_train_step += 1 
        reward = 0
        self.moves += 1
        self.history_counter += 1
        
        #calculate rewards
        if self.transitions:
            reward = score - self.last_score
            self.last_score = score
            if infos["has_won"]:
                reward += 10
            if infos["has_lost"]:
                reward -= 10
            if reward == 0:
                reward -= 1
            # update rewards for command from last step
            self.update_qvalues(self.transitions[-1],reward)

        # Debug output
        if(self.no_train_step % 1 == 0):
            print("")
            #print("Last 3 admissible commands: ", last_commands)
            print("train step:" + str(self.no_train_step))
            print("last reward:" + str(reward))
            command = "last command: "
            if self.transitions:
                for id in self.transitions[-1]:
                    command += " " + self._get_word_by_id(id)
                print(command)
        
        #save last command in order to calculate rewards in next step
        self.transitions.append(cmds[best_index])
        
        if done:
            if(infos["has_won"]):
                print("-------- WON GAME ----------")
            else:
                print("-------- LOST GAME ----------")
            print(" ")
            self.last_score = 0
            self.moves = 0
            self.transitions = []
            self.command_history = []
            
        return action

# %%
# testing text similarity
agent = CustomAgent()
agent.train()
tok1= agent._tokenize("Cook a meal.")
tok2= agent._tokenize("Prepare the food.")
sim = agent.calc_similarity(tok1,tok2)
print(sim)
# Out:
# 0.4282114982604981

# %% [markdown]
# ## Training the Agent
# - just training on the easiest game

# %%
agent = CustomAgent()
agent.train()
starttime = time()
for i in range(2):
    print("-------------------------------------")
    print("GAME: " + str(i+1))
    print("-------------------------------------")
    play(agent, gamefiles[5])
print("Trained in {:.2f} secs".format(time() - starttime))
# Out:
# -------------------------------------
# GAME: 1
# -------------------------------------
# tw-cooking-recipe1+take1-11Oeig8bSVdGSp78.ulx
# train step:1
# last reward:0
#
# train step:2
# last reward:-1
# last command:  examine red hot pepper
#
# train step:3
# last reward:-1
# last command:  examine red hot pepper
#
# train step:4
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:5
# last reward:1
# last command:  prepare meal
#
# train step:6
# last reward:-1
# last command:  take yellow bell pepper from counter
#
# train step:7
# last reward:-1
# last command:  drop meal
#
# train step:8
# last reward:-1
# last command:  take meal
#
# train step:9
# last reward:-1
# last command:  put meal on counter
#
# train step:10
# last reward:-1
# last command:  cook yellow bell pepper with oven
#
# train step:11
# last reward:-1
# last command:  cook yellow bell pepper with oven
#
# train step:12
# last reward:-1
# last command:  look
#
# train step:13
# last reward:-1
# last command:  look
#
# train step:14
# last reward:-1
# last command:  examine red apple
#
# train step:15
# last reward:-1
# last command:  examine red apple
#
# train step:16
# last reward:-1
# last command:  close fridge
#
# train step:17
# last reward:-1
# last command:  take cookbook from table
#
# train step:18
# last reward:-1
# last command:  drop cookbook
#
# train step:19
# last reward:-1
# last command:  open fridge
#
# train step:20
# last reward:-1
# last command:  take meal from counter
#
# train step:21
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:22
# last reward:0
#
# train step:23
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:24
# last reward:1
# last command:  prepare meal
#
# train step:25
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:26
# last reward:0
#
# train step:27
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:28
# last reward:1
# last command:  prepare meal
#
# train step:29
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:30
# last reward:0
#
# train step:31
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:32
# last reward:1
# last command:  prepare meal
#
# train step:33
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:34
# last reward:0
#
# train step:35
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:36
# last reward:1
# last command:  prepare meal
#
# train step:37
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:38
# last reward:0
#
# train step:39
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:40
# last reward:1
# last command:  prepare meal
#
# train step:41
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:42
# last reward:0
#
# train step:43
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:44
# last reward:1
# last command:  prepare meal
#
# train step:45
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:46
# last reward:0
#
# train step:47
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:48
# last reward:1
# last command:  prepare meal
#
# train step:49
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:50
# last reward:0
#
# train step:51
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:52
# last reward:1
# last command:  prepare meal
#
# train step:53
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:54
# last reward:0
#
# train step:55
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:56
# last reward:1
# last command:  prepare meal
#
# train step:57
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .  	avg. steps:   4.7; avg. score:  3.0 / 3.
# -------------------------------------
# GAME: 2
# -------------------------------------
# tw-cooking-recipe1+take1-11Oeig8bSVdGSp78.ulx
# train step:58
# last reward:0
#
# train step:59
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:60
# last reward:1
# last command:  prepare meal
#
# train step:61
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:62
# last reward:0
#
# train step:63
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:64
# last reward:1
# last command:  prepare meal
#
# train step:65
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:66
# last reward:0
#
# train step:67
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:68
# last reward:1
# last command:  prepare meal
#
# train step:69
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:70
# last reward:0
#
# train step:71
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:72
# last reward:1
# last command:  prepare meal
#
# train step:73
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:74
# last reward:0
#
# train step:75
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:76
# last reward:1
# last command:  prepare meal
#
# train step:77
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:78
# last reward:0
#
# train step:79
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:80
# last reward:1
# last command:  prepare meal
#
# train step:81
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:82
# last reward:0
#
# train step:83
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:84
# last reward:1
# last command:  prepare meal
#
# train step:85
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:86
# last reward:0
#
# train step:87
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:88
# last reward:1
# last command:  prepare meal
#
# train step:89
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:90
# last reward:0
#
# train step:91
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:92
# last reward:1
# last command:  prepare meal
#
# train step:93
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .
# train step:94
# last reward:0
#
# train step:95
# last reward:1
# last command:  take red hot pepper from counter
#
# train step:96
# last reward:1
# last command:  prepare meal
#
# train step:97
# last reward:11
# last command:  eat meal
# -------- WON GAME ----------
#
# .  	avg. steps:   3.0; avg. score:  3.0 / 3.
# Trained in 31.49 secs

# %%
agent.test()
play(agent, gamefiles[5])
# Out:
# tw-cooking-recipe1+take1-11Oeig8bSVdGSp78.ulx..........  	avg. steps:   3.0; avg. score:  3.0 / 3.

# %%
for i in range(len(agent.qvalues)):
    if(agent.qvalues[i] != 0 ):
        print(agent._get_word_by_id(i) + " : " + str(agent.qvalues[i]))
# Out:
# apple : -2
# bell : -3
# close : -1
# cook : -2
# cookbook : -2
# counter : 17
# drop : -2
# eat : 220
# examine : -4
# fridge : -2
# from : 17
# hot : 18
# look : -2
# meal : 236
# on : -1
# open : -1
# oven : -2
# pepper : 15
# prepare : 20
# put : -1
# red : 16
# table : -1
# take : 16
# with : -2
# yellow : -3

# %%
agent.train()
starttime = time()
for i in range(2):
    print("-------------------------------------")
    print("GAME: " + str(i+1))
    print("-------------------------------------")
    play(agent, gamefiles[8])
print("Trained in {:.2f} secs".format(time() - starttime))
# Out:
# -------------------------------------
# GAME: 1
# -------------------------------------
# tw-cooking-recipe2+take2+cut+open-BnYEixa9iJKmFZxO.ulx
# train step:1
# last reward:0
#
# train step:2
# last reward:-1
# last command:  take red hot pepper from counter
#
# train step:3
# last reward:-1
# last command:  eat red hot pepper
#
# train step:4
# last reward:-1
# last command:  take red potato from counter
#
# train step:5
# last reward:-1
# last command:  take cookbook from counter
#
# train step:6
# last reward:-1
# last command:  take purple potato from counter
#
# train step:7
# last reward:1
# last command:  take yellow potato from counter
#
# train step:8
# last reward:-10
# last command:  eat yellow potato
# -------- LOST GAME ----------
#
# .
# train step:9
# last reward:0
#
# train step:10
# last reward:-1
# last command:  take red hot pepper from counter
#
# train step:11
# last reward:-1
# last command:  eat red hot pepper
#
# train step:12
# last reward:-1
# last command:  take red potato from counter
#
# train step:13
# last reward:-1
# last command:  take cookbook from counter
#
# train step:14
# last reward:-1
# last command:  take purple potato from counter
#
# train step:15
# last reward:-1
# last command:  take knife from table
#
# train step:16
# last reward:-1
# last command:  examine counter
#
# train step:17
# last reward:-1
# last command:  put red potato on counter
#
# train step:18
# last reward:-1
# last command:  take red potato from counter
#
# train step:19
# last reward:1
# last command:  take yellow potato from counter
#
# train step:20
# last reward:-10
# last command:  eat yellow potato
# -------- LOST GAME ----------
#
# .
# train step:21
# last reward:0
#
# train step:22
# last reward:-1
# last command:  take red hot pepper from counter
#
# train step:23
# last reward:-1
# last command:  eat red hot pepper
#
# train step:24
# last reward:-1
# last command:  take cookbook from counter
#
# train step:25
# last reward:-1
# last command:  take knife from table
#
# train step:26
# last reward:-1
# last command:  take red potato from counter
#
# train step:27
# last reward:-1
# last command:  examine counter
#
# train step:28
# last reward:-1
# last command:  put knife on counter
#
# train step:29
# last reward:-1
# last command:  take knife from counter
#
# train step:30
# last reward:-1
# last command:  examine counter
#
# train step:31
# last reward:-1
# last command:  look
#
# train step:32
# last reward:-1
# last command:  open fridge
#
# train step:33
# last reward:-1
# last command:  take orange bell pepper from fridge
#
# train step:34
# last reward:-1
# last command:  eat orange bell pepper
#
# train step:35
# last reward:-1
# last command:  take cilantro from fridge
#
# train step:36
# last reward:-1
# last command:  eat cilantro
#
# train step:37
# last reward:1
# last command:  take yellow bell pepper from fridge
#
# train step:38
# last reward:-1
# last command:  prepare meal
#
# train step:39
# last reward:-10
# last command:  eat yellow bell pepper
# -------- LOST GAME ----------
#
# .
# train step:40
# last reward:0
#
# train step:41
# last reward:-1
# last command:  take red hot pepper from counter
#
# train step:42
# last reward:-1
# last command:  eat red hot pepper
#
# train step:43
# last reward:-1
# last command:  take cookbook from counter
#
# train step:44
# last reward:-1
# last command:  take knife from table
#
# train step:45
# last reward:-1
# last command:  look
#
# train step:46
# last reward:-1
# last command:  put cookbook on counter
#
# train step:47
# last reward:-1
# last command:  take cookbook from counter
#
# train step:48
# last reward:-1
# last command:  open fridge
#
# train step:49
# last reward:-1
# last command:  take cilantro from fridge
#
# train step:50
# last reward:-1
# last command:  eat cilantro
#
# train step:51
# last reward:-1
# last command:  insert knife into fridge
#
# train step:52
# last reward:-1
# last command:  insert cookbook into fridge
#
# train step:53
# last reward:-1
# last command:  examine stove
#
# train step:54
# last reward:-1
# last command:  look
#
# train step:55
# last reward:-1
# last command:  take orange bell pepper from fridge
#
# train step:56
# last reward:-1
# last command:  eat orange bell pepper
#
# train step:57
# last reward:-1
# last command:  examine stove
#
# train step:58
# last reward:-1
# last command:  look
#
# train step:59
# last reward:-1
# last command:  take red potato from counter
#
# train step:60
# last reward:-1
# last command:  cook red potato with oven
#
# train step:61
# last reward:-1
# last command:  eat red potato
#
# train step:62
# last reward:-1
# last command:  close fridge
#
# train step:63
# last reward:-1
# last command:  examine stove
#
# train step:64
# last reward:-1
# last command:  look
#
# train step:65
# last reward:-1
# last command:  examine oven
#
# train step:66
# last reward:-1
# last command:  examine stove
#
# train step:67
# last reward:-1
# last command:  look
#
# train step:68
# last reward:-1
# last command:  open fridge
#
# train step:69
# last reward:-1
# last command:  close fridge
#
# train step:70
# last reward:-1
# last command:  take purple potato from counter
#
# train step:71
# last reward:-1
# last command:  cook purple potato with stove
#
# train step:72
# last reward:-1
# last command:  eat purple potato
#
# train step:73
# last reward:-1
# last command:  look
#
# train step:74
# last reward:-1
# last command:  examine oven
#
# train step:75
# last reward:-1
# last command:  examine table
#
# train step:76
# last reward:-1
# last command:  open fridge
#
# train step:77
# last reward:-1
# last command:  close fridge
#
# train step:78
# last reward:-1
# last command:  look
#
# train step:79
# last reward:-1
# last command:  examine oven
#
# train step:80
# last reward:-1
# last command:  examine table
#
# train step:81
# last reward:-1
# last command:  look
#
# train step:82
# last reward:-1
# last command:  open fridge
#
# train step:83
# last reward:-1
# last command:  take knife from fridge
#
# train step:84
# last reward:-1
# last command:  drop knife
#
# train step:85
# last reward:-1
# last command:  take knife
#
# train step:86
# last reward:-1
# last command:  put knife on counter
#
# train step:87
# last reward:-1
# last command:  take knife from counter
#
# train step:88
# last reward:-1
# last command:  drop knife
#
# train step:89
# last reward:-1
# last command:  close fridge
#
# train step:90
# last reward:-1
# last command:  examine stove
# -------- LOST GAME ----------
#
# .
# train step:91
# last reward:0
#
# train step:92
# last reward:-1
# last command:  examine red hot pepper
#
# train step:93
# last reward:-1
# last command:  examine red hot pepper
#
# train step:94
# last reward:-1
# last command:  take red hot pepper from counter
#
# train step:95
# last reward:-1
# last command:  eat red hot pepper
#
# train step:96
# last reward:-1
# last command:  take cookbook from counter
#
# train step:97
# last reward:-1
# last command:  drop cookbook
#
# train step:98
# last reward:-1
# last command:  take knife from table
#
# train step:99
# last reward:-1
# last command:  put knife on table
#
# train step:100
# last reward:-1
# last command:  look
#
# train step:101
# last reward:-1
# last command:  take knife from table
#
# train step:102
# last reward:-1
# last command:  put knife on stove
#
# train step:103
# last reward:-1
# last command:  look
#
# train step:104
# last reward:-1
# last command:  open fridge
#
# train step:105
# last reward:-1
# last command:  examine orange bell pepper
#
# train step:106
# last reward:-1
# last command:  take orange bell pepper from fridge
#
# train step:107
# last reward:-1
# last command:  eat orange bell pepper
#
# train step:108
# last reward:-1
# last command:  examine cilantro
#
# train step:109
# last reward:-1
# last command:  close fridge
#
# train step:110
# last reward:-1
# last command:  take red potato from counter
#
# train step:111
# last reward:-1
# last command:  cook red potato with oven
#
# train step:112
# last reward:-1
# last command:  eat red potato
#
# train step:113
# last reward:-1
# last command:  look
#
# train step:114
# last reward:-1
# last command:  take cookbook
#
# train step:115
# last reward:-1
# last command:  drop cookbook
#
# train step:116
# last reward:-1
# last command:  look
#
# train step:117
# last reward:-1
# last command:  open fridge
#
# train step:118
# last reward:-1
# last command:  examine cilantro
#
# train step:119
# last reward:-1
# last command:  close fridge
#
# train step:120
# last reward:-1
# last command:  take knife from stove
#
# train step:121
# last reward:-1
# last command:  put knife on stove
#
# train step:122
# last reward:-1
# last command:  examine oven
#
# train step:123
# last reward:-1
# last command:  take purple potato from counter
#
# train step:124
# last reward:-1
# last command:  cook purple potato with oven
#
# train step:125
# last reward:-1
# last command:  eat purple potato
#
# train step:126
# last reward:-1
# last command:  look
# train step:127
# last reward:-1
# last command:  open fridge
#
# train step:128
# last reward:-1
# last command:  examine cilantro
#
# train step:129
# last reward:-1
# last command:  close fridge
#
# train step:130
# last reward:-1
# last command:  take cookbook
#
# train step:131
# last reward:-1
# last command:  drop cookbook
#
# train step:132
# last reward:-1
# last command:  look
#
# train step:133
# last reward:-1
# last command:  take knife from stove
#
# train step:134
# last reward:-1
# last command:  put knife on table
#
# train step:135
# last reward:-1
# last command:  take knife from table
#
# train step:136
# last reward:-1
# last command:  put knife on counter
#
# train step:137
# last reward:-1
# last command:  examine oven
#
# train step:138
# last reward:-1
# last command:  look
#
# train step:139
# last reward:-1
# last command:  open fridge
#
# train step:140
# last reward:-1
# last command:  examine cilantro
#
# train step:141
# last reward:-1
# last command:  close fridge
# -------- LOST GAME ----------
#
# .
# train step:142
# last reward:0
#
# train step:143
# last reward:-1
# last command:  examine red hot pepper
#
# train step:144
# last reward:-1
# last command:  examine red hot pepper
#
# train step:145
# last reward:-1
# last command:  examine red hot pepper
#
# train step:146
# last reward:-1
# last command:  examine red hot pepper
#
# train step:147
# last reward:-1
# last command:  take red hot pepper from counter
#
# train step:148
# last reward:-1
# last command:  eat red hot pepper
#
# train step:149
# last reward:-1
# last command:  take cookbook from counter
#
# train step:150
# last reward:-1
# last command:  drop cookbook
#
# train step:151
# last reward:-1
# last command:  look
#
# train step:152
# last reward:-1
# last command:  open fridge
#
# train step:153
# last reward:-1
# last command:  examine orange bell pepper
#
# train step:154
# last reward:-1
# last command:  take orange bell pepper from fridge
#
# train step:155
# last reward:-1
# last command:  eat orange bell pepper
#
# train step:156
# last reward:-1
# last command:  close fridge
#
# train step:157
# last reward:-1
# last command:  look
#
# train step:158
# last reward:-1
# last command:  take purple potato from counter
#
# train step:159
# last reward:-1
# last command:  cook purple potato with stove
#
# train step:160
# last reward:-1
# last command:  eat purple potato
#
# train step:161
# last reward:-1
# last command:  look
#
# train step:162
# last reward:-1
# last command:  take knife from table
#
# train step:163
# last reward:-1
# last command:  put knife on table
#
# train step:164
# last reward:-1
# last command:  open fridge
#
# train step:165
# last reward:-1
# last command:  examine cilantro
#
# train step:166
# last reward:-1
# last command:  close fridge
#
# train step:167
# last reward:-1
# last command:  look
#
# train step:168
# last reward:-1
# last command:  examine oven
#
# train step:169
# last reward:-1
# last command:  examine stove
#
# train step:170
# last reward:-1
# last command:  take cookbook
#
# train step:171
# last reward:-1
# last command:  drop cookbook
#
# train step:172
# last reward:-1
# last command:  look
#
# train step:173
# last reward:-1
# last command:  open fridge
#
# train step:174
# last reward:-1
# last command:  examine cilantro
#
# train step:175
# last reward:-1
# last command:  close fridge
#
# train step:176
# last reward:-1
# last command:  take red potato from counter
#
# train step:177
# last reward:-1
# last command:  cook red potato with oven
#
# train step:178
# last reward:-1
# last command:  eat red potato
#
# train step:179
# last reward:-1
# last command:  take knife from table
#
# train step:180
# last reward:-1
# last command:  put knife on table
#
# train step:181
# last reward:-1
# last command:  look
#
# train step:182
# last reward:-1
# last command:  open fridge
#
# train step:183
# last reward:-1
# last command:  examine cilantro
#
# train step:184
# last reward:-1
# last command:  close fridge
#
# train step:185
# last reward:-1
# last command:  look
#
# train step:186
# last reward:-1
# last command:  take knife from table
#
# train step:187
# last reward:-1
# last command:  put knife on stove
#
# train step:188
# last reward:-1
# last command:  examine oven
#
# train step:189
# last reward:-1
# last command:  examine stove
#
# train step:190
# last reward:-1
# last command:  take cookbook
#
# train step:191
# last reward:-1
# last command:  drop cookbook
#
# train step:192
# last reward:-1
# last command:  look
# -------- LOST GAME ----------
#
# .
# train step:193
# last reward:0
#
# train step:194
# last reward:-1
# last command:  take red hot pepper from counter
#
# train step:195
# last reward:-1
# last command:  eat red hot pepper
#
# train step:196
# last reward:-1
# last command:  take cookbook from counter
#
# train step:197
# last reward:-1
# last command:  drop cookbook
#
# train step:198
# last reward:-1
# last command:  open fridge
#
# train step:199
# last reward:-1
# last command:  examine orange bell pepper
#
# train step:200
# last reward:-1
# last command:  take orange bell pepper from fridge
#
# train step:201
# last reward:-1
# last command:  eat orange bell pepper
#
# train step:202
# last reward:-1
# last command:  examine cilantro
#
# train step:203
# last reward:-1
# last command:  close fridge
#
# train step:204
# last reward:-1
# last command:  take purple potato from counter
#
# train step:205
# last reward:-1
# last command:  cook purple potato with oven
#
# train step:206
# last reward:-1
# last command:  eat purple potato
#
# train step:207
# last reward:-1
# last command:  look
#
# train step:208
# last reward:-1
# last command:  open fridge
#
# train step:209
# last reward:-1
# last command:  examine cilantro
#
# train step:210
# last reward:-1
# last command:  close fridge
#
# train step:211
# last reward:-1
# last command:  look
#
# train step:212
# last reward:-1
# last command:  take knife from table
#
# train step:213
# last reward:-1
# last command:  put knife on stove
#
# train step:214
# last reward:-1
# last command:  examine oven
#
# train step:215
# last reward:-1
# last command:  look
#
# train step:216
# last reward:-1
# last command:  open fridge
#
# train step:217
# last reward:-1
# last command:  examine cilantro
#
# train step:218
# last reward:-1
# last command:  close fridge
#
# train step:219
# last reward:-1
# last command:  take red potato from counter
#
# train step:220
# last reward:-1
# last command:  cook red potato with oven
#
# train step:221
# last reward:-1
# last command:  eat red potato
#
# train step:222
# last reward:-1
# last command:  look
#
# train step:223
# last reward:-1
# last command:  take knife from stove
#
# train step:224
# last reward:-1
# last command:  put knife on stove
#
# train step:225
# last reward:-1
# last command:  examine oven
#
# train step:226
# last reward:-1
# last command:  look
#
# train step:227
# last reward:-1
# last command:  open fridge
#
# train step:228
# last reward:-1
# last command:  examine cilantro
#
# train step:229
# last reward:-1
# last command:  examine yellow bell pepper
#
# train step:230
# last reward:-1
# last command:  examine cilantro
#
# train step:231
# last reward:-1
# last command:  close fridge
#
# train step:232
# last reward:-1
# last command:  take knife from stove
#
# train step:233
# last reward:-1
# last command:  put knife on table
#
# train step:234
# last reward:-1
# last command:  look
#
# train step:235
# last reward:-1
# last command:  take cookbook
#
# train step:236
# last reward:-1
# last command:  drop cookbook
#
# train step:237
# last reward:-1
# last command:  open fridge
#
# train step:238
# last reward:-1
# last command:  examine yellow bell pepper
#
# train step:239
# last reward:-1
# last command:  examine cilantro
#
# train step:240
# last reward:-1
# last command:  close fridge
#
# train step:241
# last reward:-1
# last command:  take knife from table
#
# train step:242
# last reward:-1
# last command:  put knife on table
#
# train step:243
# last reward:-1
# last command:  look
# -------- LOST GAME ----------
#
# .
# train step:244
# last reward:0
#
# train step:245
# last reward:-1
# last command:  take red hot pepper from counter
#
# train step:246
# last reward:-1
# last command:  eat red hot pepper
#
# train step:247
# last reward:-1
# last command:  take cookbook from counter
#
# train step:248
# last reward:-1
# last command:  drop cookbook
#
# train step:249
# last reward:-1
# last command:  take purple potato from counter
#
# train step:250
# last reward:-1
# last command:  cook purple potato with oven
#
# train step:251
# last reward:-1
# last command:  eat purple potato
#
# train step:252
# last reward:-1
# last command:  look
#
# train step:253
# last reward:-1
# last command:  open fridge
#
# train step:254
# last reward:-1
# last command:  examine orange bell pepper
#
# train step:255
# last reward:-1
# last command:  take orange bell pepper from fridge
#
# train step:256
# last reward:-1
# last command:  eat orange bell pepper
# train step:257
# last reward:-1
# last command:  examine cilantro
#
# train step:258
# last reward:-1
# last command:  close fridge
#
# train step:259
# last reward:-1
# last command:  look
#
# train step:260
# last reward:-1
# last command:  examine oven
#
# train step:261
# last reward:-1
# last command:  examine stove
#
# train step:262
# last reward:-1
# last command:  take red potato from counter
#
# train step:263
# last reward:-1
# last command:  cook red potato with oven
#
# train step:264
# last reward:-1
# last command:  eat red potato
#
# train step:265
# last reward:-1
# last command:  look
#
# train step:266
# last reward:-1
# last command:  open fridge
#
# train step:267
# last reward:-1
# last command:  close fridge
#
# train step:268
# last reward:-1
# last command:  take knife from table
#
# train step:269
# last reward:-1
# last command:  put knife on table
#
# train step:270
# last reward:-1
# last command:  look
#
# train step:271
# last reward:-1
# last command:  examine stove
#
# train step:272
# last reward:-1
# last command:  open fridge
#
# train step:273
# last reward:-1
# last command:  examine yellow bell pepper
#
# train step:274
# last reward:-1
# last command:  examine cilantro
#
# train step:275
# last reward:-1
# last command:  examine yellow bell pepper
#
# train step:276
# last reward:-1
# last command:  close fridge
#
# train step:277
# last reward:-1
# last command:  look
#
# train step:278
# last reward:-1
# last command:  take cookbook
#
# train step:279
# last reward:-1
# last command:  drop cookbook
#
# train step:280
# last reward:-1
# last command:  take knife from table
#
# train step:281
# last reward:-1
# last command:  put knife on stove
#
# train step:282
# last reward:-1
# last command:  look
#
# train step:283
# last reward:-1
# last command:  open fridge
#
# train step:284
# last reward:-1
# last command:  close fridge
#
# train step:285
# last reward:-1
# last command:  examine oven
#
# train step:286
# last reward:-1
# last command:  take knife from stove
#
# train step:287
# last reward:-1
# last command:  put knife on stove
#
# train step:288
# last reward:-1
# last command:  look
#
# train step:289
# last reward:1
# last command:  take yellow potato from counter
#
# train step:290
# last reward:-10
# last command:  eat yellow potato
# -------- LOST GAME ----------
#
# .
# train step:291
# last reward:0
#
# train step:292
# last reward:-1
# last command:  take red hot pepper from counter
#
# train step:293
# last reward:-1
# last command:  eat red hot pepper
#
# train step:294
# last reward:-1
# last command:  take cookbook from counter
#
# train step:295
# last reward:-1
# last command:  drop cookbook
#
# train step:296
# last reward:-1
# last command:  take purple potato from counter
#
# train step:297
# last reward:-1
# last command:  cook purple potato with oven
#
# train step:298
# last reward:-1
# last command:  eat purple potato
#
# train step:299
# last reward:-1
# last command:  open fridge
#
# train step:300
# last reward:-1
# last command:  examine orange bell pepper
#
# train step:301
# last reward:-1
# last command:  examine cilantro
#
# train step:302
# last reward:-1
# last command:  examine cilantro
#
# train step:303
# last reward:-1
# last command:  examine orange bell pepper
#
# train step:304
# last reward:-1
# last command:  take orange bell pepper from fridge
#
# train step:305
# last reward:-1
# last command:  eat orange bell pepper
#
# train step:306
# last reward:-1
# last command:  close fridge
#
# train step:307
# last reward:-1
# last command:  look
#
# train step:308
# last reward:-1
# last command:  take knife from table
#
# train step:309
# last reward:-1
# last command:  put knife on table
#
# train step:310
# last reward:-1
# last command:  look
#
# train step:311
# last reward:-1
# last command:  open fridge
#
# train step:312
# last reward:-1
# last command:  close fridge
#
# train step:313
# last reward:-1
# last command:  look
#
# train step:314
# last reward:-1
# last command:  examine oven
#
# train step:315
# last reward:-1
# last command:  examine stove
#
# train step:316
# last reward:-1
# last command:  take cookbook
#
# train step:317
# last reward:-1
# last command:  drop cookbook
#
# train step:318
# last reward:-1
# last command:  look
#
# train step:319
# last reward:-1
# last command:  open fridge
#
# train step:320
# last reward:-1
# last command:  examine cilantro
#
# train step:321
# last reward:-1
# last command:  close fridge
#
# train step:322
# last reward:-1
# last command:  take red potato from counter
#
# train step:323
# last reward:-1
# last command:  cook red potato with oven
#
# train step:324
# last reward:-1
# last command:  eat red potato
#
# train step:325
# last reward:-1
# last command:  take knife from table
#
# train step:326
# last reward:-1
# last command:  put knife on table
#
# train step:327
# last reward:-1
# last command:  look
#
# train step:328
# last reward:-1
# last command:  open fridge
#
# train step:329
# last reward:-1
# last command:  examine cilantro
#
# train step:330
# last reward:-1
# last command:  examine yellow bell pepper
#
# train step:331
# last reward:-1
# last command:  close fridge
#
# train step:332
# last reward:-1
# last command:  look
#
# train step:333
# last reward:-1
# last command:  take knife from table
#
# train step:334
# last reward:-1
# last command:  put knife on stove
#
# train step:335
# last reward:-1
# last command:  take knife from stove
#
# train step:336
# last reward:-1
# last command:  put knife on counter
#
# train step:337
# last reward:-1
# last command:  examine oven
#
# train step:338
# last reward:-1
# last command:  look
#
# train step:339
# last reward:-1
# last command:  open fridge
#
# train step:340
# last reward:-1
# last command:  examine cilantro
#
# train step:341
# last reward:-1
# last command:  examine yellow bell pepper
# -------- LOST GAME ----------
#
# .
# train step:342
# last reward:0
#
# train step:343
# last reward:-1
# last command:  take red hot pepper from counter
#
# train step:344
# last reward:-1
# last command:  eat red hot pepper
#
# train step:345
# last reward:-1
# last command:  take cookbook from counter
#
# train step:346
# last reward:-1
# last command:  drop cookbook
#
# train step:347
# last reward:-1
# last command:  take purple potato from counter
#
# train step:348
# last reward:-1
# last command:  cook purple potato with oven
#
# train step:349
# last reward:-1
# last command:  eat purple potato
#
# train step:350
# last reward:-1
# last command:  look
#
# train step:351
# last reward:-1
# last command:  open fridge
#
# train step:352
# last reward:-1
# last command:  examine orange bell pepper
#
# train step:353
# last reward:-1
# last command:  take orange bell pepper from fridge
#
# train step:354
# last reward:-1
# last command:  eat orange bell pepper
#
# train step:355
# last reward:-1
# last command:  close fridge
#
# train step:356
# last reward:-1
# last command:  look
#
# train step:357
# last reward:-1
# last command:  examine oven
#
# train step:358
# last reward:-1
# last command:  examine stove
#
# train step:359
# last reward:-1
# last command:  look
#
# train step:360
# last reward:-1
# last command:  open fridge
#
# train step:361
# last reward:-1
# last command:  close fridge
#
# train step:362
# last reward:-1
# last command:  take cookbook
#
# train step:363
# last reward:-1
# last command:  drop cookbook
#
# train step:364
# last reward:-1
# last command:  take knife from table
#
# train step:365
# last reward:-1
# last command:  put knife on table
#
# train step:366
# last reward:-1
# last command:  look
#
# train step:367
# last reward:-1
# last command:  take red potato from counter
#
# train step:368
# last reward:-1
# last command:  cook red potato with oven
#
# train step:369
# last reward:-1
# last command:  eat red potato
#
# train step:370
# last reward:-1
# last command:  examine stove
#
# train step:371
# last reward:-1
# last command:  open fridge
#
# train step:372
# last reward:-1
# last command:  examine cilantro
#
# train step:373
# last reward:-1
# last command:  close fridge
#
# train step:374
# last reward:-1
# last command:  look
#
# train step:375
# last reward:-1
# last command:  take knife from table
#
# train step:376
# last reward:-1
# last command:  put knife on stove
#
# train step:377
# last reward:-1
# last command:  examine oven
#
# train step:378
# last reward:-1
# last command:  look
#
# train step:379
# last reward:-1
# last command:  open fridge
#
# train step:380
# last reward:-1
# last command:  examine cilantro
#
# train step:381
# last reward:-1
# last command:  examine yellow bell pepper
#
# train step:382
# last reward:-1
# last command:  examine cilantro
#
# train step:383
# last reward:-1
# last command:  close fridge
#
# train step:384
# last reward:-1
# last command:  take cookbook
#
# train step:385
# last reward:-1
# last command:  drop cookbook
#
# train step:386
# last reward:-1
# last command:  look
#
# train step:387
# last reward:-1
# last command:  take knife from stove
# train step:388
# last reward:-1
# last command:  put knife on stove
#
# train step:389
# last reward:-1
# last command:  open fridge
#
# train step:390
# last reward:-1
# last command:  examine yellow bell pepper
#
# train step:391
# last reward:-1
# last command:  examine cilantro
#
# train step:392
# last reward:-1
# last command:  close fridge
# -------- LOST GAME ----------
#
# .  	avg. steps:  38.2; avg. score:  0.4 / 6.
# -------------------------------------
# GAME: 2
# -------------------------------------
# tw-cooking-recipe2+take2+cut+open-BnYEixa9iJKmFZxO.ulx
# train step:393
# last reward:0
#
# train step:394
# last reward:-1
# last command:  take red hot pepper from counter
#
# train step:395
# last reward:-1
# last command:  eat red hot pepper
#
# train step:396
# last reward:-1
# last command:  take cookbook from counter
#
# train step:397
# last reward:-1
# last command:  drop cookbook
#
# train step:398
# last reward:-1
# last command:  take purple potato from counter
#
# train step:399
# last reward:-1
# last command:  cook purple potato with oven
#
# train step:400
# last reward:-1
# last command:  eat purple potato
#
# train step:401
# last reward:-1
# last command:  look
#
# train step:402
# last reward:-1
# last command:  open fridge
#
# train step:403
# last reward:-1
# last command:  examine orange bell pepper
#
# train step:404
# last reward:-1
# last command:  take orange bell pepper from fridge
#
# train step:405
# last reward:-1
# last command:  eat orange bell pepper
#
# train step:406
# last reward:-1
# last command:  examine cilantro
#
# train step:407
# last reward:-1
# last command:  close fridge
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-109-64f185671689> in <module>
#       5     print("GAME: " + str(i+1))
#       6     print("-------------------------------------")
# ----> 7     play(agent, gamefiles[8])
#       8 print("Trained in {:.2f} secs".format(time() - starttime))
#
# <ipython-input-3-a3a9b7d49d4b> in play(agent, path, max_step, nb_episodes, verbose)
#      27         while not done:
#      28             # the agent chooses an action
# ---> 29             command = agent.act(obs, score, done, infos)
#      30             # carry out action and update parameters
#      31             obs, score, done, infos = env.step(command)
#
# <ipython-input-103-4e4cfd92b904> in act(self, obs, score, done, infos)
#     271         for i in range(len(infos["admissible_commands"])):
#     272             cmds.append(self._tokenize(infos["admissible_commands"][i]))
# --> 273         best_index = self.choose_best_cmd(cmds, recipe_tok)
#     274         action = infos["admissible_commands"][best_index]
#     275
#
# <ipython-input-103-4e4cfd92b904> in choose_best_cmd(self, commands, recipe_tok)
#     196         avg_qvalues =  []
#     197         for cmd in commands:
# --> 198             qval = self.calc_avg_qvalue(cmd) + self.calc_similarity(cmd,recipe_tok)*10
#     199             #print(str(self.tok_to_nlp(cmd)) + ": " +  str(self.calc_similarity(cmd,recipe_tok)))
#     200             avg_qvalues.append(qval)
#
# <ipython-input-103-4e4cfd92b904> in calc_similarity(self, tok1, tok2)
#     162         """calculate the similarity between two nlp strings"""
#     163         text1 = self.tok_to_nlp(tok1)
# --> 164         text2 = self.tok_to_nlp(tok2)
#     165         sim = 0.0
#     166         # sometimes error when cost is negative...
#
# <ipython-input-103-4e4cfd92b904> in tok_to_nlp(self, tok1)
#     156         for id in tok1:
#     157             text += self._get_word_by_id(id) + " "
# --> 158         text = self.nlp(text)
#     159         return text
#     160
#
# ~/venv3/lib/python3.6/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     388             if not hasattr(proc, "__call__"):
#     389                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 390             doc = proc(doc, **component_cfg.get(name, {}))
#     391             if doc is None:
#     392                 raise ValueError(Errors.E005.format(name=name))
#
# KeyboardInterrupt:

# %%
# versuche
wordids = agent._tokenize("cook a meal")
print(wordids)

print(agent._get_word_id("cook"))
print(agent._get_word_by_id(4664))
# Out:
# [4664, 785, 11449]
# 4664
# cook

# %%
def play_render(agent,gamefile):
    requested_infos = agent.select_additional_infos
    env_id = textworld.gym.register_games([gamefile], requested_infos)

    env = gym.make(env_id)
    obs, infos = env.reset()

    env.render()  # Print the initial observation.

    score = 0
    done = False
    while not done:
        command = agent.act(obs,score,done,infos)
        ob, score, done, infos = env.step(command)
        env.render()

# %%
agent.test()
play_render(agent, gamefiles[5])
# Out:
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# You are hungry! Let's cook a delicious meal. Check the cookbook in the kitchen
# for the recipe. Once done, enjoy your meal!
#
# -= Kitchen =-
# You're now in the kitchen. I guess you better just go and list everything you
# see here.
#
# You hear a noise behind you and spin around, but you can't see anything other
# than a fridge. The fridge is empty! This is the worst thing that could possibly
# happen, ever! You see a closed oven. You make out a table. The table is massive.
# On the table you can make out a cookbook. You can make out a counter. The
# counter is vast. On the counter you can make out a sliced fried red hot pepper,
# a red apple, a yellow bell pepper and a knife. You smell an intriguing smell,
# and follow it to a stove. You shudder, but continue examining the stove. But the
# thing is empty, unfortunately. Hm. Oh well
#
# > take red hot pepper from counter
# You take the red hot pepper from the counter.
#
#
#
# Your score has just gone up by one point.
#
# > prepare meal
# Adding the meal to your inventory.
#
#
#
# Your score has just gone up by one point.
#
# > eat meal
# You eat the meal. Not bad.
#
#
# Your score has just gone up by one point.
#
#
#                                *** The End ***
#
# You scored 3 out of a possible 3, in 5 turn(s).
#
#
# Would you like to QUIT?
# >
